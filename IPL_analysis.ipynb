# %% [markdown]
# <h1 style="color:red; text-align:center; border:2px solid red; font-size:3rem"> IPL ANALYSIS 2024</h1>

# %% [markdown]
# <h1> ALL Data Taken From <a href="https://codebasics.io/challenge/codebasics-resume-project-challenge/13"> Code Basics</a> </h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Exploration

# %%
df_players = pd.read_csv("datasets/dim_players.csv")

# %%
df_players.head()
# Out:
#              name         team    battingStyle        bowlingStyle  \
# 0  RuturajGaikwad  Super Kings  Right hand Bat  Right arm Offbreak
# 1    FafduPlessis  Super Kings  Right hand Bat            Legbreak
# 2    RobinUthappa  Super Kings  Right hand Bat    Right arm Medium
# 3        MoeenAli  Super Kings   Left hand Bat  Right arm Offbreak
# 4     ShubmanGill          KKR  Right hand Bat  Right arm Offbreak
#
#            playingRole
# 0               Batter
# 1  Middle order Batter
# 2               Batter
# 3   Batting Allrounder
# 4       Opening Batter

# %%
df_players.shape
# Out:
# (292, 5)

# %%
df_players.playingRole.unique()
# Out:
# array(['Batter', 'Middle order Batter', 'Batting Allrounder',
#        'Opening Batter', 'Allrounder', 'Bowling Allrounder',
#        'Wicketkeeper Batter', 'Top order Batter', 'Bowler'], dtype=object)

# %%
df_players.playingRole.value_counts()
# Out:
# playingRole
# Bowler                 117
# Allrounder              41
# Wicketkeeper Batter     29
# Top order Batter        27
# Bowling Allrounder      23
# Batting Allrounder      19
# Middle order Batter     13
# Batter                  12
# Opening Batter          11
# Name: count, dtype: int64

# %%
df_players.team.unique()
# Out:
# array(['Super Kings', 'KKR', 'Capitals', 'RCB', 'Mumbai', 'Sunrisers',
#        'Royals', 'Punjab Kings', 'Titans', 'Super Giants'], dtype=object)

# %%
df_players.team.value_counts()
# Out:
# team
# Mumbai          39
# Punjab Kings    38
# Sunrisers       35
# KKR             35
# Royals          33
# RCB             30
# Capitals        29
# Super Kings     28
# Titans          13
# Super Giants    12
# Name: count, dtype: int64

# %%
df_players.isna().sum()
# Out:
# name            0
# team            0
# battingStyle    0
# bowlingStyle    0
# playingRole     0
# dtype: int64

# %%
df_players.battingStyle.unique()
# Out:
# array(['Right hand Bat', 'Left hand Bat'], dtype=object)

# %%
df_players.battingStyle.value_counts()
# Out:
# battingStyle
# Right hand Bat    210
# Left hand Bat      82
# Name: count, dtype: int64

# %%
df_players["bowlingStyle"].value_counts()
# Out:
# bowlingStyle
# Right arm Offbreak                                52
# Right arm Medium                                  47
# Right arm Fast medium                             28
# Right arm Fast                                    26
# Not Available                                     23
# Legbreak                                          21
# Slow Left arm Orthodox                            21
# Legbreak Googly                                   16
# Right arm Medium fast                             16
# Left arm Fast medium                              12
# Left arm Medium fast                              10
# Left arm Medium                                    5
# Left arm Wrist spin                                4
# Left arm Fast                                      3
# Right arm Offbreak, Legbreak Googly                2
# Right arm Offbreak, Legbreak                       2
# Right arm Medium, Right arm Offbreak               2
# Right arm Medium, Right arm Offbreak, Legbreak     1
# Slow Left arm Orthodox, Left arm Wrist spin        1
# Name: count, dtype: int64

# %%
df_match = pd.read_csv("datasets/dim_match_summary.csv")

# %%
df_match
# Out:
#             team1        team2        winner     margin     matchDate match_id
# 0     Super Kings          KKR   Super Kings    27 runs  Oct 15, 2021  T203817
# 1        Capitals          KKR           KKR  3 wickets  Oct 13, 2021  T206442
# 2             RCB          KKR           KKR  4 wickets  Oct 11, 2021  T208597
# 3        Capitals  Super Kings   Super Kings  4 wickets  Oct 10, 2021  T201819
# 4        Capitals          RCB           RCB  7 wickets   Oct 8, 2021  T205942
# ..            ...          ...           ...        ...           ...      ...
# 201        Mumbai          RCB           RCB  8 wickets   Apr 2, 2023  T202485
# 202        Royals    Sunrisers        Royals    72 runs   Apr 2, 2023  T209117
# 203  Super Giants     Capitals  Super Giants    50 runs   Apr 1, 2023  T208512
# 204  Punjab Kings          KKR  Punjab Kings     7 runs   Apr 1, 2023  T202853
# 205   Super Kings       Titans        Titans  5 wickets  Mar 31, 2023  T201566
#
# [206 rows x 6 columns]

# %%
df_match.isna().sum()
# Out:
# team1        0
# team2        0
# winner       0
# margin       0
# matchDate    0
# match_id     0
# dtype: int64

# %%
type(df_match["matchDate"][0])
# Out:
# str

# %%
df_bating = pd.read_csv("datasets/fact_bating_summary.csv")

df_bowling = pd.read_csv("datasets/fact_bowling_summary.csv")

# %%
df_bating.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76
# 2         out    31     15   0   3  206.66
# 3     not_out    37     20   2   3  185.00
# 4         out    51     43   6   0  118.60

# %%
df_bating.isna().sum()
# Out:
# match_id       0
# match          0
# teamInnings    0
# battingPos     0
# batsmanName    0
# out/not_out    0
# runs           0
# balls          0
# 4s             0
# 6s             0
# SR             0
# dtype: int64

# %%
df_bating.dtypes
# Out:
# match_id       object
# match          object
# teamInnings    object
# battingPos      int64
# batsmanName    object
# out/not_out    object
# runs            int64
# balls           int64
# 4s              int64
# 6s              int64
# SR             object
# dtype: object

# %%
df_bating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match_id     3268 non-null   object
#  1   match        3268 non-null   object
#  2   teamInnings  3268 non-null   object
#  3   battingPos   3268 non-null   int64
#  4   batsmanName  3268 non-null   object
#  5   out/not_out  3268 non-null   object
#  6   runs         3268 non-null   int64
#  7   balls        3268 non-null   int64
#  8   4s           3268 non-null   int64
#  9   6s           3268 non-null   int64
#  10  SR           3268 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 281.0+ KB

# %%
type(df_bating["SR"][0])
# Out:
# str

# %%
df_bowling.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls
# 0    33        0     11.0   6   2   3      0        0
# 1    32        1      8.0   8   1   2      0        0
# 2    56        0     14.0   4   7   2      2        0
# 3    38        0      9.5   5   2   2      0        1
# 4    26        2      6.5   6   0   1      1        0

# %%
df_bating[df_bating.match_id == "T203817"]
# Out:
#    match_id               match  teamInnings  battingPos        batsmanName  \
# 0   T203817  Super Kings Vs KKR  Super Kings           1     RuturajGaikwad
# 1   T203817  Super Kings Vs KKR  Super Kings           2       FafduPlessis
# 2   T203817  Super Kings Vs KKR  Super Kings           3       RobinUthappa
# 3   T203817  Super Kings Vs KKR  Super Kings           4           MoeenAli
# 4   T203817  Super Kings Vs KKR          KKR           1        ShubmanGill
# 5   T203817  Super Kings Vs KKR          KKR           2      VenkateshIyer
# 6   T203817  Super Kings Vs KKR          KKR           3         NitishRana
# 7   T203817  Super Kings Vs KKR          KKR           4        SunilNarine
# 8   T203817  Super Kings Vs KKR          KKR           5         EoinMorgan
# 9   T203817  Super Kings Vs KKR          KKR           6      DineshKarthik
# 10  T203817  Super Kings Vs KKR          KKR           7      ShakibAlHasan
# 11  T203817  Super Kings Vs KKR          KKR           8      RahulTripathi
# 12  T203817  Super Kings Vs KKR          KKR           9     LockieFerguson
# 13  T203817  Super Kings Vs KKR          KKR          10         ShivamMavi
# 14  T203817  Super Kings Vs KKR          KKR          11  VarunChakravarthy
#
#    out/not_out  runs  balls  4s  6s      SR
# 0          out    32     27   3   1  118.51
# 1          out    86     59   7   3  145.76
# 2          out    31     15   0   3  206.66
# 3      not_out    37     20   2   3  185.00
# 4          out    51     43   6   0  118.60
# 5          out    50     32   5   3  156.25
# 6          out     0      1   0   0    0.00
# 7          out     2      2   0   0  100.00
# 8          out     4      8   0   0   50.00
# 9          out     9      7   0   1  128.57
# 10         out     0      1   0   0    0.00
# 11         out     2      3   0   0   66.66
# 12     not_out    18     11   1   1  163.63
# 13         out    20     13   1   2  153.84
# 14     not_out     0      0   0   0       -

# %%
df_bowling[df_bowling.match_id == "T203817"]
# Out:
#    match_id               match  bowlingTeam         bowlerName  overs  \
# 0   T203817  Super Kings Vs KKR          KKR      ShakibAlHasan    3.0
# 1   T203817  Super Kings Vs KKR          KKR         ShivamMavi    4.0
# 2   T203817  Super Kings Vs KKR          KKR     LockieFerguson    4.0
# 3   T203817  Super Kings Vs KKR          KKR  VarunChakravarthy    4.0
# 4   T203817  Super Kings Vs KKR          KKR        SunilNarine    4.0
# 5   T203817  Super Kings Vs KKR          KKR      VenkateshIyer    1.0
# 6   T203817  Super Kings Vs KKR  Super Kings       DeepakChahar    4.0
# 7   T203817  Super Kings Vs KKR  Super Kings      JoshHazlewood    4.0
# 8   T203817  Super Kings Vs KKR  Super Kings      ShardulThakur    4.0
# 9   T203817  Super Kings Vs KKR  Super Kings        DwayneBravo    4.0
# 10  T203817  Super Kings Vs KKR  Super Kings     RavindraJadeja    4.0
#
#     maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls
# 0        0    33        0    11.00   6   2   3      0        0
# 1        0    32        1     8.00   8   1   2      0        0
# 2        0    56        0    14.00   4   7   2      2        0
# 3        0    38        0     9.50   5   2   2      0        1
# 4        0    26        2     6.50   6   0   1      1        0
# 5        0     5        0     5.00   2   0   0      0        0
# 6        0    32        1     8.00  10   4   1      1        0
# 7        0    29        2     7.25  10   2   1      2        0
# 8        0    38        3     9.50  11   3   1      4        1
# 9        0    29        1     7.25   9   1   2      0        0
# 10       0    37        2     9.25   9   3   2      1        0

# %%
df_bowling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2436 entries, 0 to 2435
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match_id     2436 non-null   object
#  1   match        2436 non-null   object
#  2   bowlingTeam  2436 non-null   object
#  3   bowlerName   2436 non-null   object
#  4   overs        2436 non-null   float64
#  5   maiden       2436 non-null   int64
#  6   runs         2436 non-null   int64
#  7   wickets      2436 non-null   int64
#  8   economy      2436 non-null   float64
#  9   0s           2436 non-null   int64
#  10  4s           2436 non-null   int64
#  11  6s           2436 non-null   int64
#  12  wides        2436 non-null   int64
#  13  noBalls      2436 non-null   int64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 266.6+ KB

# %% [markdown]
# <h2>  Data Cleaning </h2>

# %%
df_match
# Out:
#             team1        team2        winner     margin     matchDate match_id
# 0     Super Kings          KKR   Super Kings    27 runs  Oct 15, 2021  T203817
# 1        Capitals          KKR           KKR  3 wickets  Oct 13, 2021  T206442
# 2             RCB          KKR           KKR  4 wickets  Oct 11, 2021  T208597
# 3        Capitals  Super Kings   Super Kings  4 wickets  Oct 10, 2021  T201819
# 4        Capitals          RCB           RCB  7 wickets   Oct 8, 2021  T205942
# ..            ...          ...           ...        ...           ...      ...
# 201        Mumbai          RCB           RCB  8 wickets   Apr 2, 2023  T202485
# 202        Royals    Sunrisers        Royals    72 runs   Apr 2, 2023  T209117
# 203  Super Giants     Capitals  Super Giants    50 runs   Apr 1, 2023  T208512
# 204  Punjab Kings          KKR  Punjab Kings     7 runs   Apr 1, 2023  T202853
# 205   Super Kings       Titans        Titans  5 wickets  Mar 31, 2023  T201566
#
# [206 rows x 6 columns]

# %%
type(df_match["matchDate"][0])
# Out:
# str

# %%
df_match["matchDate"].unique()
# Out:
# array(['Oct 15, 2021', 'Oct 13, 2021', 'Oct 11, 2021', 'Oct 10, 2021',
#        'Oct 8, 2021', 'Oct 7, 2021', 'Oct 6, 2021', 'Oct 5, 2021',
#        'Oct 4, 2021', 'Oct 3, 2021', 'Oct 2, 2021', 'Oct 1, 2021',
#        'Sep 30, 2021', 'Sep 29, 2021', 'Sep 28, 2021', 'Sep 27, 2021',
#        'Sep 26, 2021', 'Sep 25, 2021', 'Sep 24, 2021', 'Sep 23, 2021',
#        'Sep 22, 2021', 'Sep 21, 2021', 'Sep 20, 2021', 'Sep 19, 2021',
#        'May 2, 2021', 'May 1, 2021', 'Apr 30, 2021', 'Apr 29, 2021',
#        'Apr 28, 2021', 'Apr 27, 2021', 'Apr 26, 2021', 'Apr 25, 2021',
#        'Apr 24, 2021', 'Apr 23, 2021', 'Apr 22, 2021', 'Apr 21, 2021',
#        'Apr 20, 2021', 'Apr 19, 2021', 'Apr 18, 2021', 'Apr 17, 2021',
#        'Apr 16, 2021', 'Apr 15, 2021', 'Apr 14, 2021', 'Apr 13, 2021',
#        'Apr 12, 2021', 'Apr 11, 2021', 'Apr 10, 2021', 'Apr 9, 2021',
#        'May 29, 2022', 'May 27, 2022', 'May 25, 2022', 'May 24, 2022',
#        'May 22, 2022', 'May 21, 2022', 'May 20, 2022', 'May 19, 2022',
#        'May 18, 2022', 'May 17, 2022', 'May 16, 2022', 'May 15, 2022',
#        'May 14, 2022', 'May 13, 2022', 'May 12, 2022', 'May 11, 2022',
#        'May 10, 2022', 'May 9, 2022', 'May 8, 2022', 'May 7, 2022',
#        'May 6, 2022', 'May 5, 2022', 'May 4, 2022', 'May 3, 2022',
#        'May 2, 2022', 'May 1, 2022', 'Apr 30, 2022', 'Apr 29, 2022',
#        'Apr 28, 2022', 'Apr 27, 2022', 'Apr 26, 2022', 'Apr 25, 2022',
#        'Apr 24, 2022', 'Apr 23, 2022', 'Apr 22, 2022', 'Apr 21, 2022',
#        'Apr 20, 2022', 'Apr 19, 2022', 'Apr 18, 2022', 'Apr 17, 2022',
#        'Apr 16, 2022', 'Apr 15, 2022', 'Apr 14, 2022', 'Apr 13, 2022',
#        'Apr 12, 2022', 'Apr 11, 2022', 'Apr 10, 2022', 'Apr 9, 2022',
#        'Apr 8, 2022', 'Apr 7, 2022', 'Apr 6, 2022', 'Apr 5, 2022',
#        'Apr 4, 2022', 'Apr 3, 2022', 'Apr 2, 2022', 'Apr 1, 2022',
#        'Mar 31, 2022', 'Mar 30, 2022', 'Mar 29, 2022', 'Mar 28, 2022',
#        'Mar 27, 2022', 'Mar 26, 2022', 'May 28-29, 2023', 'May 26, 2023',
#        'May 24, 2023', 'May 23, 2023', 'May 21, 2023', 'May 20, 2023',
#        'May 19, 2023', 'May 18, 2023', 'May 17, 2023', 'May 16, 2023',
#        'May 15, 2023', 'May 14, 2023', 'May 13, 2023', 'May 12, 2023',
#        'May 11, 2023', 'May 10, 2023', 'May 9, 2023', 'May 8, 2023',
#        'May 7, 2023', 'May 6, 2023', 'May 5, 2023', 'May 4, 2023',
#        'May 3, 2023', 'May 2, 2023', 'May 1, 2023', 'Apr 30, 2023',
#        'Apr 29, 2023', 'Apr 28, 2023', 'Apr 27, 2023', 'Apr 26, 2023',
#        'Apr 25, 2023', 'Apr 24, 2023', 'Apr 23, 2023', 'Apr 22, 2023',
#        'Apr 21, 2023', 'Apr 20, 2023', 'Apr 19, 2023', 'Apr 18, 2023',
#        'Apr 17, 2023', 'Apr 16, 2023', 'Apr 15, 2023', 'Apr 14, 2023',
#        'Apr 13, 2023', 'Apr 12, 2023', 'Apr 11, 2023', 'Apr 10, 2023',
#        'Apr 9, 2023', 'Apr 8, 2023', 'Apr 7, 2023', 'Apr 6, 2023',
#        'Apr 5, 2023', 'Apr 4, 2023', 'Apr 3, 2023', 'Apr 2, 2023',
#        'Apr 1, 2023', 'Mar 31, 2023'], dtype=object)

# %%
df_match.replace("May 28-29, 2023", "May 29, 2023", inplace=True)

# %%
df_match["matchDate"].unique()
# Out:
# array(['Oct 15, 2021', 'Oct 13, 2021', 'Oct 11, 2021', 'Oct 10, 2021',
#        'Oct 8, 2021', 'Oct 7, 2021', 'Oct 6, 2021', 'Oct 5, 2021',
#        'Oct 4, 2021', 'Oct 3, 2021', 'Oct 2, 2021', 'Oct 1, 2021',
#        'Sep 30, 2021', 'Sep 29, 2021', 'Sep 28, 2021', 'Sep 27, 2021',
#        'Sep 26, 2021', 'Sep 25, 2021', 'Sep 24, 2021', 'Sep 23, 2021',
#        'Sep 22, 2021', 'Sep 21, 2021', 'Sep 20, 2021', 'Sep 19, 2021',
#        'May 2, 2021', 'May 1, 2021', 'Apr 30, 2021', 'Apr 29, 2021',
#        'Apr 28, 2021', 'Apr 27, 2021', 'Apr 26, 2021', 'Apr 25, 2021',
#        'Apr 24, 2021', 'Apr 23, 2021', 'Apr 22, 2021', 'Apr 21, 2021',
#        'Apr 20, 2021', 'Apr 19, 2021', 'Apr 18, 2021', 'Apr 17, 2021',
#        'Apr 16, 2021', 'Apr 15, 2021', 'Apr 14, 2021', 'Apr 13, 2021',
#        'Apr 12, 2021', 'Apr 11, 2021', 'Apr 10, 2021', 'Apr 9, 2021',
#        'May 29, 2022', 'May 27, 2022', 'May 25, 2022', 'May 24, 2022',
#        'May 22, 2022', 'May 21, 2022', 'May 20, 2022', 'May 19, 2022',
#        'May 18, 2022', 'May 17, 2022', 'May 16, 2022', 'May 15, 2022',
#        'May 14, 2022', 'May 13, 2022', 'May 12, 2022', 'May 11, 2022',
#        'May 10, 2022', 'May 9, 2022', 'May 8, 2022', 'May 7, 2022',
#        'May 6, 2022', 'May 5, 2022', 'May 4, 2022', 'May 3, 2022',
#        'May 2, 2022', 'May 1, 2022', 'Apr 30, 2022', 'Apr 29, 2022',
#        'Apr 28, 2022', 'Apr 27, 2022', 'Apr 26, 2022', 'Apr 25, 2022',
#        'Apr 24, 2022', 'Apr 23, 2022', 'Apr 22, 2022', 'Apr 21, 2022',
#        'Apr 20, 2022', 'Apr 19, 2022', 'Apr 18, 2022', 'Apr 17, 2022',
#        'Apr 16, 2022', 'Apr 15, 2022', 'Apr 14, 2022', 'Apr 13, 2022',
#        'Apr 12, 2022', 'Apr 11, 2022', 'Apr 10, 2022', 'Apr 9, 2022',
#        'Apr 8, 2022', 'Apr 7, 2022', 'Apr 6, 2022', 'Apr 5, 2022',
#        'Apr 4, 2022', 'Apr 3, 2022', 'Apr 2, 2022', 'Apr 1, 2022',
#        'Mar 31, 2022', 'Mar 30, 2022', 'Mar 29, 2022', 'Mar 28, 2022',
#        'Mar 27, 2022', 'Mar 26, 2022', 'May 29, 2023', 'May 26, 2023',
#        'May 24, 2023', 'May 23, 2023', 'May 21, 2023', 'May 20, 2023',
#        'May 19, 2023', 'May 18, 2023', 'May 17, 2023', 'May 16, 2023',
#        'May 15, 2023', 'May 14, 2023', 'May 13, 2023', 'May 12, 2023',
#        'May 11, 2023', 'May 10, 2023', 'May 9, 2023', 'May 8, 2023',
#        'May 7, 2023', 'May 6, 2023', 'May 5, 2023', 'May 4, 2023',
#        'May 3, 2023', 'May 2, 2023', 'May 1, 2023', 'Apr 30, 2023',
#        'Apr 29, 2023', 'Apr 28, 2023', 'Apr 27, 2023', 'Apr 26, 2023',
#        'Apr 25, 2023', 'Apr 24, 2023', 'Apr 23, 2023', 'Apr 22, 2023',
#        'Apr 21, 2023', 'Apr 20, 2023', 'Apr 19, 2023', 'Apr 18, 2023',
#        'Apr 17, 2023', 'Apr 16, 2023', 'Apr 15, 2023', 'Apr 14, 2023',
#        'Apr 13, 2023', 'Apr 12, 2023', 'Apr 11, 2023', 'Apr 10, 2023',
#        'Apr 9, 2023', 'Apr 8, 2023', 'Apr 7, 2023', 'Apr 6, 2023',
#        'Apr 5, 2023', 'Apr 4, 2023', 'Apr 3, 2023', 'Apr 2, 2023',
#        'Apr 1, 2023', 'Mar 31, 2023'], dtype=object)

# %%
df_match["matchDate"] = pd.to_datetime(df_match["matchDate"], format="%b %d, %Y")

# %%
df_match.head()
# Out:
#          team1        team2       winner     margin  matchDate match_id
# 0  Super Kings          KKR  Super Kings    27 runs 2021-10-15  T203817
# 1     Capitals          KKR          KKR  3 wickets 2021-10-13  T206442
# 2          RCB          KKR          KKR  4 wickets 2021-10-11  T208597
# 3     Capitals  Super Kings  Super Kings  4 wickets 2021-10-10  T201819
# 4     Capitals          RCB          RCB  7 wickets 2021-10-08  T205942

# %%
type(df_match["matchDate"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_match.dtypes
# Out:
# team1                object
# team2                object
# winner               object
# margin               object
# matchDate    datetime64[ns]
# match_id             object
# dtype: object

# %% [markdown]
# **Creating New Column as season for taking records of season 1, 2, 3**

# %%
years = list(df_match["matchDate"].dt.year.unique())

# %%
type(years)
# Out:
# list

# %%
years
# Out:
# [np.int32(2021), np.int32(2022), np.int32(2023)]

# %%
years.sort()

# %%
years
# Out:
# [np.int32(2021), np.int32(2022), np.int32(2023)]

# %%
year_to_season = {
    year : f"Season {i+1}"
    for i, year in enumerate(sorted(df_match["matchDate"].dt.year.unique()))
}
year_to_season
# Out:
# {np.int32(2021): 'Season 1',
#  np.int32(2022): 'Season 2',
#  np.int32(2023): 'Season 3'}

# %%
df_match["season"] = df_match["matchDate"].dt.year.map(year_to_season)

df_match
# Out:
#             team1        team2        winner     margin  matchDate match_id  \
# 0     Super Kings          KKR   Super Kings    27 runs 2021-10-15  T203817
# 1        Capitals          KKR           KKR  3 wickets 2021-10-13  T206442
# 2             RCB          KKR           KKR  4 wickets 2021-10-11  T208597
# 3        Capitals  Super Kings   Super Kings  4 wickets 2021-10-10  T201819
# 4        Capitals          RCB           RCB  7 wickets 2021-10-08  T205942
# ..            ...          ...           ...        ...        ...      ...
# 201        Mumbai          RCB           RCB  8 wickets 2023-04-02  T202485
# 202        Royals    Sunrisers        Royals    72 runs 2023-04-02  T209117
# 203  Super Giants     Capitals  Super Giants    50 runs 2023-04-01  T208512
# 204  Punjab Kings          KKR  Punjab Kings     7 runs 2023-04-01  T202853
# 205   Super Kings       Titans        Titans  5 wickets 2023-03-31  T201566
#
#        season
# 0    Season 1
# 1    Season 1
# 2    Season 1
# 3    Season 1
# 4    Season 1
# ..        ...
# 201  Season 3
# 202  Season 3
# 203  Season 3
# 204  Season 3
# 205  Season 3
#
# [206 rows x 7 columns]

# %%
df_bating.head(20)
# Out:
#    match_id               match  teamInnings  battingPos        batsmanName  \
# 0   T203817  Super Kings Vs KKR  Super Kings           1     RuturajGaikwad
# 1   T203817  Super Kings Vs KKR  Super Kings           2       FafduPlessis
# 2   T203817  Super Kings Vs KKR  Super Kings           3       RobinUthappa
# 3   T203817  Super Kings Vs KKR  Super Kings           4           MoeenAli
# 4   T203817  Super Kings Vs KKR          KKR           1        ShubmanGill
# 5   T203817  Super Kings Vs KKR          KKR           2      VenkateshIyer
# 6   T203817  Super Kings Vs KKR          KKR           3         NitishRana
# 7   T203817  Super Kings Vs KKR          KKR           4        SunilNarine
# 8   T203817  Super Kings Vs KKR          KKR           5         EoinMorgan
# 9   T203817  Super Kings Vs KKR          KKR           6      DineshKarthik
# 10  T203817  Super Kings Vs KKR          KKR           7      ShakibAlHasan
# 11  T203817  Super Kings Vs KKR          KKR           8      RahulTripathi
# 12  T203817  Super Kings Vs KKR          KKR           9     LockieFerguson
# 13  T203817  Super Kings Vs KKR          KKR          10         ShivamMavi
# 14  T203817  Super Kings Vs KKR          KKR          11  VarunChakravarthy
# 15  T206442     Capitals Vs KKR     Capitals           1        PrithviShaw
# 16  T206442     Capitals Vs KKR     Capitals           2      ShikharDhawan
# 17  T206442     Capitals Vs KKR     Capitals           3      MarcusStoinis
# 18  T206442     Capitals Vs KKR     Capitals           4        ShreyasIyer
# 19  T206442     Capitals Vs KKR     Capitals           5        RishabhPant
#
#    out/not_out  runs  balls  4s  6s      SR
# 0          out    32     27   3   1  118.51
# 1          out    86     59   7   3  145.76
# 2          out    31     15   0   3  206.66
# 3      not_out    37     20   2   3  185.00
# 4          out    51     43   6   0  118.60
# 5          out    50     32   5   3  156.25
# 6          out     0      1   0   0    0.00
# 7          out     2      2   0   0  100.00
# 8          out     4      8   0   0   50.00
# 9          out     9      7   0   1  128.57
# 10         out     0      1   0   0    0.00
# 11         out     2      3   0   0   66.66
# 12     not_out    18     11   1   1  163.63
# 13         out    20     13   1   2  153.84
# 14     not_out     0      0   0   0       -
# 15         out    18     12   2   1  150.00
# 16         out    36     39   1   2   92.30
# 17         out    18     23   1   0   78.26
# 18     not_out    30     27   1   1  111.11
# 19         out     6      6   1   0  100.00

# %%
type(df_bating["SR"][0])
# Out:
# str

# %%
df_bating[df_bating.SR == "-"]
# Out:
#      match_id                        match   teamInnings  battingPos  \
# 14    T203817           Super Kings Vs KKR           KKR          11
# 30    T206442              Capitals Vs KKR           KKR           9
# 39    T208597                   RCB Vs KKR           RCB           9
# 62    T201819      Capitals Vs Super Kings   Super Kings           8
# 84    T201979          Mumbai Vs Sunrisers        Mumbai          11
# 195   T207754          RCB Vs Punjab Kings           RCB           7
# 249   T201051          KKR Vs Punjab Kings  Punjab Kings           7
# 312   T206700              Capitals Vs KKR           KKR           9
# 370   T203188    Punjab Kings Vs Sunrisers  Punjab Kings           9
# 446   T207857       Royals Vs Punjab Kings        Royals          11
# 466   T204307                   RCB Vs KKR           KKR           3
# 527   T203694        Super Kings Vs Mumbai        Mumbai           8
# 631   T205585                KKR Vs Royals           KKR           5
# 636   T205585                KKR Vs Royals           KKR          10
# 650   T204808       Mumbai Vs Punjab Kings        Mumbai           8
# 664   T201545                Royals Vs RCB        Royals          11
# 686   T204912    Punjab Kings Vs Sunrisers  Punjab Kings           4
# 724   T209089        Super Kings Vs Royals   Super Kings          11
# 734   T209089        Super Kings Vs Royals        Royals          10
# 791   T205292  Punjab Kings Vs Super Kings  Punjab Kings          10
# 825   T202204             RCB Vs Sunrisers           RCB           9
# 836   T202204             RCB Vs Sunrisers     Sunrisers          11
# 847   T209194                Mumbai Vs KKR        Mumbai          11
# 898   T206363      Super Kings Vs Capitals      Capitals           5
# 907   T203784                Mumbai Vs RCB        Mumbai           9
# 928   T202715             Royals Vs Titans        Royals          10
# 970   T203302             Royals Vs Titans        Royals           8
# 1196  T207400       Titans Vs Super Giants  Super Giants          10
# 1208  T203087                KKR Vs Mumbai           KKR          11
# 1218  T203087                KKR Vs Mumbai        Mumbai          10
# 1245  T207464             RCB Vs Sunrisers     Sunrisers           2
# 1256  T204710          Super Giants Vs KKR  Super Giants           2
# 1294  T201720             Mumbai Vs Titans        Mumbai           8
# 1325  T207511           RCB Vs Super Kings           RCB           9
# 1326  T207511           RCB Vs Super Kings           RCB          10
# 1374  T206274     Super Kings Vs Sunrisers     Sunrisers           8
# 1480  T205212                Royals Vs RCB        Royals          10
# 1521  T208801       Super Giants Vs Mumbai        Mumbai           9
# 1628  T206892                Royals Vs KKR           KKR           2
# 1652  T206030        Super Kings Vs Titans        Titans           9
# 1660  T208958    Punjab Kings Vs Sunrisers  Punjab Kings           8
# 1700  T204555       Super Giants Vs Mumbai        Mumbai          10
# 1756  T203601           Super Kings Vs RCB   Super Kings           6
# 2258  T201082     Capitals Vs Punjab Kings  Punjab Kings           9
# 2322  T204453                RCB Vs Royals        Royals           8
# 2334  T208032     Punjab Kings Vs Capitals  Punjab Kings           9
# 2436  T201181          Punjab Kings Vs KKR           KKR           7
# 2583  T204100             Royals Vs Mumbai        Royals           9
# 2762  T204462       Punjab Kings Vs Mumbai  Punjab Kings           8
# 2786  T208595       Titans Vs Super Giants  Super Giants           8
# 2836  T209410          RCB Vs Punjab Kings  Punjab Kings          11
# 2895  T204210             Titans Vs Royals        Titans           9
# 3108  T209590    Sunrisers Vs Super Giants     Sunrisers           9
# 3109  T209590    Sunrisers Vs Super Giants     Sunrisers          10
#
#              batsmanName out/not_out  runs  balls  4s  6s SR
# 14     VarunChakravarthy     not_out     0      0   0   0  -
# 30        LockieFerguson     not_out     0      0   0   0  -
# 39          GeorgeGarton     not_out     0      0   0   0  -
# 62        RavindraJadeja     not_out     0      0   0   0  -
# 84            TrentBoult     not_out     0      0   0   0  -
# 195         SrikarBharat     not_out     0      0   0   0  -
# 249          FabianAllen     not_out     0      0   0   0  -
# 312       LockieFerguson     not_out     0      0   0   0  -
# 370        MohammedShami     not_out     0      0   0   0  -
# 446     MustafizurRahman     not_out     0      0   0   0  -
# 466         AndreRussell     not_out     0      0   0   0  -
# 527       DhawalKulkarni     not_out     0      0   0   0  -
# 631           EoinMorgan         out     0      0   0   0  -
# 636       PrasidhKrishna     not_out     0      0   0   0  -
# 650          JayantYadav     not_out     0      0   0   0  -
# 664     MustafizurRahman     not_out     0      0   0   0  -
# 686       NicholasPooran         out     0      0   0   0  -
# 724         DeepakChahar     not_out     0      0   0   0  -
# 734       ChetanSakariya     not_out     0      0   0   0  -
# 791        RileyMeredith     not_out     0      0   0   0  -
# 825         HarshalPatel     not_out     0      0   0   0  -
# 836           TNatarajan     not_out     0      0   0   0  -
# 847           TrentBoult     not_out     0      0   0   0  -
# 898       ShimronHetmyer     not_out     0      0   0   0  -
# 907          RahulChahar         out     0      0   0   0  -
# 928       PrasidhKrishna     not_out     0      0   0   0  -
# 970           TrentBoult     not_out     0      0   0   0  -
# 1196  DushmanthaChameera     not_out     0      0   0   0  -
# 1208   VarunChakravarthy     not_out     0      0   0   0  -
# 1218       JaspritBumrah         out     0      0   0   0  -
# 1245      KaneWilliamson         out     0      0   0   0  -
# 1256             KLRahul         out     0      0   0   0  -
# 1294       MuruganAshwin     not_out     0      0   0   0  -
# 1325        HarshalPatel         out     0      0   0   0  -
# 1326       MohammedSiraj     not_out     0      0   0   0  -
# 1374         MarcoJansen     not_out     0      0   0   0  -
# 1480     YuzvendraChahal     not_out     0      0   0   0  -
# 1521      HrithikShokeen     not_out     0      0   0   0  -
# 1628         SunilNarine         out     0      0   0   0  -
# 1652      LockieFerguson     not_out     0      0   0   0  -
# 1660        KagisoRabada     not_out     0      0   0   0  -
# 1700       JaspritBumrah     not_out     0      0   0   0  -
# 1756             MSDhoni     not_out     0      0   0   0  -
# 2258         RahulChahar     not_out     0      0   0   0  -
# 2322  RavichandranAshwin         out     0      0   0   0  -
# 2334         RishiDhawan     not_out     0      0   0   0  -
# 2436       ShardulThakur     not_out     0      0   0   0  -
# 2583          TrentBoult     not_out     0      0   0   0  -
# 2762       MShahrukhKhan     not_out     0      0   0   0  -
# 2786        PrerakMankad     not_out     0      0   0   0  -
# 2836       ArshdeepSingh     not_out     0      0   0   0  -
# 2895       AlzarriJoseph     not_out     0      0   0   0  -
# 3108          UmranMalik         out     0      0   0   0  -
# 3109    BhuvneshwarKumar     not_out     0      0   0   0  -

# %%
df_bating.replace(to_replace={
    "SR":"-"
}, value=0.00, inplace=True)

# %%
df_bating.head(20)
# Out:
#    match_id               match  teamInnings  battingPos        batsmanName  \
# 0   T203817  Super Kings Vs KKR  Super Kings           1     RuturajGaikwad
# 1   T203817  Super Kings Vs KKR  Super Kings           2       FafduPlessis
# 2   T203817  Super Kings Vs KKR  Super Kings           3       RobinUthappa
# 3   T203817  Super Kings Vs KKR  Super Kings           4           MoeenAli
# 4   T203817  Super Kings Vs KKR          KKR           1        ShubmanGill
# 5   T203817  Super Kings Vs KKR          KKR           2      VenkateshIyer
# 6   T203817  Super Kings Vs KKR          KKR           3         NitishRana
# 7   T203817  Super Kings Vs KKR          KKR           4        SunilNarine
# 8   T203817  Super Kings Vs KKR          KKR           5         EoinMorgan
# 9   T203817  Super Kings Vs KKR          KKR           6      DineshKarthik
# 10  T203817  Super Kings Vs KKR          KKR           7      ShakibAlHasan
# 11  T203817  Super Kings Vs KKR          KKR           8      RahulTripathi
# 12  T203817  Super Kings Vs KKR          KKR           9     LockieFerguson
# 13  T203817  Super Kings Vs KKR          KKR          10         ShivamMavi
# 14  T203817  Super Kings Vs KKR          KKR          11  VarunChakravarthy
# 15  T206442     Capitals Vs KKR     Capitals           1        PrithviShaw
# 16  T206442     Capitals Vs KKR     Capitals           2      ShikharDhawan
# 17  T206442     Capitals Vs KKR     Capitals           3      MarcusStoinis
# 18  T206442     Capitals Vs KKR     Capitals           4        ShreyasIyer
# 19  T206442     Capitals Vs KKR     Capitals           5        RishabhPant
#
#    out/not_out  runs  balls  4s  6s      SR
# 0          out    32     27   3   1  118.51
# 1          out    86     59   7   3  145.76
# 2          out    31     15   0   3  206.66
# 3      not_out    37     20   2   3  185.00
# 4          out    51     43   6   0  118.60
# 5          out    50     32   5   3  156.25
# 6          out     0      1   0   0    0.00
# 7          out     2      2   0   0  100.00
# 8          out     4      8   0   0   50.00
# 9          out     9      7   0   1  128.57
# 10         out     0      1   0   0    0.00
# 11         out     2      3   0   0   66.66
# 12     not_out    18     11   1   1  163.63
# 13         out    20     13   1   2  153.84
# 14     not_out     0      0   0   0     0.0
# 15         out    18     12   2   1  150.00
# 16         out    36     39   1   2   92.30
# 17         out    18     23   1   0   78.26
# 18     not_out    30     27   1   1  111.11
# 19         out     6      6   1   0  100.00

# %%
df_bating[df_bating.SR == "-"]
# Out:
# Empty DataFrame
# Columns: [match_id, match, teamInnings, battingPos, batsmanName, out/not_out, runs, balls, 4s, 6s, SR]
# Index: []

# %%
type(df_bating["SR"][0])
# Out:
# str

# %%
df_bating["SR"]= pd.to_numeric(df_bating["SR"])

# %%
type(df_bating["SR"][0])
# Out:
# numpy.float64

# %% [markdown]
# # 3. Data Transformation

# %%
df_bating.head(2)
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76

# %%
df_bowling.head(2)
# Out:
#   match_id               match bowlingTeam     bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR     ShivamMavi    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls
# 0    33        0     11.0   6   2   3      0        0
# 1    32        1      8.0   8   1   2      0        0

# %%
df_match.head(2)
# Out:
#          team1 team2       winner     margin  matchDate match_id    season
# 0  Super Kings   KKR  Super Kings    27 runs 2021-10-15  T203817  Season 1
# 1     Capitals   KKR          KKR  3 wickets 2021-10-13  T206442  Season 1

# %%
df_players.head(2)
# Out:
#              name         team    battingStyle        bowlingStyle  \
# 0  RuturajGaikwad  Super Kings  Right hand Bat  Right arm Offbreak
# 1    FafduPlessis  Super Kings  Right hand Bat            Legbreak
#
#            playingRole
# 0               Batter
# 1  Middle order Batter

# %%
df_bating_merged = pd.merge(df_bating,df_players, left_on="batsmanName", right_on="name" )

df_bating_merged.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR            name         team  \
# 0         out    32     27   3   1  118.51  RuturajGaikwad  Super Kings
# 1         out    86     59   7   3  145.76    FafduPlessis  Super Kings
# 2         out    31     15   0   3  206.66    RobinUthappa  Super Kings
# 3     not_out    37     20   2   3  185.00        MoeenAli  Super Kings
# 4         out    51     43   6   0  118.60     ShubmanGill          KKR
#
#      battingStyle        bowlingStyle          playingRole
# 0  Right hand Bat  Right arm Offbreak               Batter
# 1  Right hand Bat            Legbreak  Middle order Batter
# 2  Right hand Bat    Right arm Medium               Batter
# 3   Left hand Bat  Right arm Offbreak   Batting Allrounder
# 4  Right hand Bat  Right arm Offbreak       Opening Batter

# %%
df_bating_merged.drop(columns="name", inplace=True)
df_bating_merged.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR         team    battingStyle  \
# 0         out    32     27   3   1  118.51  Super Kings  Right hand Bat
# 1         out    86     59   7   3  145.76  Super Kings  Right hand Bat
# 2         out    31     15   0   3  206.66  Super Kings  Right hand Bat
# 3     not_out    37     20   2   3  185.00  Super Kings   Left hand Bat
# 4         out    51     43   6   0  118.60          KKR  Right hand Bat
#
#          bowlingStyle          playingRole
# 0  Right arm Offbreak               Batter
# 1            Legbreak  Middle order Batter
# 2    Right arm Medium               Batter
# 3  Right arm Offbreak   Batting Allrounder
# 4  Right arm Offbreak       Opening Batter

# %%
df_bowling_merged = pd.merge(df_bowling,df_players, left_on="bowlerName", right_on="name" )
df_bowling_merged.drop(columns="name", inplace=True)
df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls team    battingStyle  \
# 0    33        0     11.0   6   2   3      0        0  KKR   Left hand Bat
# 1    32        1      8.0   8   1   2      0        0  KKR  Right hand Bat
# 2    56        0     14.0   4   7   2      2        0  KKR  Right hand Bat
# 3    38        0      9.5   5   2   2      0        1  KKR  Right hand Bat
# 4    26        2      6.5   6   0   1      1        0  KKR   Left hand Bat
#
#              bowlingStyle         playingRole
# 0  Slow Left arm Orthodox          Allrounder
# 1   Right arm Fast medium              Bowler
# 2          Right arm Fast              Bowler
# 3         Legbreak Googly              Bowler
# 4      Right arm Offbreak  Bowling Allrounder

# %% [markdown]
# # 4. Insight Generation (PRIMARY)

# %% [markdown]
# # 1. Top 10 batsmen based on past 3 years total runs scored.

# %%
top_runs = df_bating.groupby("batsmanName")["runs"].sum().sort_values(ascending=False).head(10)

top_runs
# Out:
# batsmanName
# ShubmanGill        1851
# FafduPlessis       1831
# RuturajGaikwad     1593
# KLRahul            1516
# JosButtler         1509
# ShikharDhawan      1392
# ViratKohli         1385
# SanjuSamson        1304
# SuryakumarYadav    1225
# GlennMaxwell       1214
# Name: runs, dtype: int64

# %%
top_runs.plot(kind="bar", color="orange")
plt.title("Top 10 batsmen based on past 3 years total runs scored",fontsize="20", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Total Runs", fontsize="10", fontweight="bold")
plt.xlabel("Batsman Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style="whitegrid")

# Prepare data
df_runs = top_runs.reset_index()
df_runs.columns = ['Batsman', 'Runs']

# Sort for clarity (if not already sorted)
df_runs = df_runs.sort_values(by="Runs", ascending=False)

# Plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    data=df_runs,
    x='Batsman',
    y='Runs',
    color='orange',
    edgecolor='black'
)

# Title and labels
plt.title("Top 10 Batsmen Based on Total Runs Scored\n(Past 3 Years)", 
          fontsize=14, fontweight="bold", pad=15)
plt.xlabel("Batsman", fontsize=12, fontweight="bold")
plt.ylabel("Total Runs", fontsize=12, fontweight="bold")

# Tick styling
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# Grid styling
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Add run values above bars
for index, row in df_runs.iterrows():
    plt.text(x=index, y=row['Runs'] + 5, s=f"{row['Runs']}", 
             ha='center', va='bottom', fontsize=9, fontweight='semibold')

# Layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Top 10 batsmen based on past 3 years batting average. (min 60 balls faced in each season)

# %%
df_match.head()
# Out:
#          team1        team2       winner     margin  matchDate match_id  \
# 0  Super Kings          KKR  Super Kings    27 runs 2021-10-15  T203817
# 1     Capitals          KKR          KKR  3 wickets 2021-10-13  T206442
# 2          RCB          KKR          KKR  4 wickets 2021-10-11  T208597
# 3     Capitals  Super Kings  Super Kings  4 wickets 2021-10-10  T201819
# 4     Capitals          RCB          RCB  7 wickets 2021-10-08  T205942
#
#      season
# 0  Season 1
# 1  Season 1
# 2  Season 1
# 3  Season 1
# 4  Season 1

# %%
df_bating_merged.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR         team    battingStyle  \
# 0         out    32     27   3   1  118.51  Super Kings  Right hand Bat
# 1         out    86     59   7   3  145.76  Super Kings  Right hand Bat
# 2         out    31     15   0   3  206.66  Super Kings  Right hand Bat
# 3     not_out    37     20   2   3  185.00  Super Kings   Left hand Bat
# 4         out    51     43   6   0  118.60          KKR  Right hand Bat
#
#          bowlingStyle          playingRole
# 0  Right arm Offbreak               Batter
# 1            Legbreak  Middle order Batter
# 2    Right arm Medium               Batter
# 3  Right arm Offbreak   Batting Allrounder
# 4  Right arm Offbreak       Opening Batter

# %%
df_bating_merged["outs"] = df_bating_merged["out/not_out"].apply(lambda x: 1 if x.strip().lower() != "not_out" else 0)
df_bating_merged.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR         team    battingStyle  \
# 0         out    32     27   3   1  118.51  Super Kings  Right hand Bat
# 1         out    86     59   7   3  145.76  Super Kings  Right hand Bat
# 2         out    31     15   0   3  206.66  Super Kings  Right hand Bat
# 3     not_out    37     20   2   3  185.00  Super Kings   Left hand Bat
# 4         out    51     43   6   0  118.60          KKR  Right hand Bat
#
#          bowlingStyle          playingRole  outs
# 0  Right arm Offbreak               Batter     1
# 1            Legbreak  Middle order Batter     1
# 2    Right arm Medium               Batter     1
# 3  Right arm Offbreak   Batting Allrounder     0
# 4  Right arm Offbreak       Opening Batter     1

# %%
df_bating_merged_season = pd.merge(df_bating_merged, df_match, on="match_id")

# %%
df_bating_merged_season.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s  ...    battingStyle        bowlingStyle  \
# 0         out    32     27   3   1  ...  Right hand Bat  Right arm Offbreak
# 1         out    86     59   7   3  ...  Right hand Bat            Legbreak
# 2         out    31     15   0   3  ...  Right hand Bat    Right arm Medium
# 3     not_out    37     20   2   3  ...   Left hand Bat  Right arm Offbreak
# 4         out    51     43   6   0  ...  Right hand Bat  Right arm Offbreak
#
#            playingRole outs        team1  team2       winner   margin  \
# 0               Batter    1  Super Kings    KKR  Super Kings  27 runs
# 1  Middle order Batter    1  Super Kings    KKR  Super Kings  27 runs
# 2               Batter    1  Super Kings    KKR  Super Kings  27 runs
# 3   Batting Allrounder    0  Super Kings    KKR  Super Kings  27 runs
# 4       Opening Batter    1  Super Kings    KKR  Super Kings  27 runs
#
#    matchDate    season
# 0 2021-10-15  Season 1
# 1 2021-10-15  Season 1
# 2 2021-10-15  Season 1
# 3 2021-10-15  Season 1
# 4 2021-10-15  Season 1
#
# [5 rows x 22 columns]

# %%
balls_group = df_bating_merged_season.groupby(["batsmanName","season"])["balls"].sum().reset_index()

balls_group
# Out:
#          batsmanName    season  balls
# 0       ABdeVilliers  Season 1    211
# 1         AaronFinch  Season 2     61
# 2        AbdulBasith  Season 3      1
# 3         AbdulSamad  Season 1     87
# 4         AbdulSamad  Season 2      7
# ..               ...       ...    ...
# 496  YashasviJaiswal  Season 2    194
# 497  YashasviJaiswal  Season 3    382
# 498     YudhvirSingh  Season 3      2
# 499  YuzvendraChahal  Season 1     27
# 500  YuzvendraChahal  Season 2      8
#
# [501 rows x 3 columns]

# %%
balls_group[balls_group["batsmanName"]=="YashasviJaiswal"]
# Out:
#          batsmanName    season  balls
# 495  YashasviJaiswal  Season 1    168
# 496  YashasviJaiswal  Season 2    194
# 497  YashasviJaiswal  Season 3    382

# %%
eligble_batsman = balls_group[balls_group["balls"]>=60].groupby("batsmanName").count()
eligble_batsman
# Out:
#                   season  balls
# batsmanName
# ABdeVilliers           1      1
# AaronFinch             1      1
# AbdulSamad             2      2
# AbhinavManohar         2      2
# AbhishekSharma         3      3
# ...                  ...    ...
# VijayShankar           1      1
# ViratKohli             3      3
# WashingtonSundar       2      2
# WriddhimanSaha         3      3
# YashasviJaiswal        3      3
#
# [108 rows x 2 columns]

# %%
eligble_batsman_all_3_season = eligble_batsman[eligble_batsman["season"]==3]

eligble_batsman_all_3_season
# Out:
#                  season  balls
# batsmanName
# AbhishekSharma        3      3
# AidenMarkram          3      3
# AmbatiRayudu          3      3
# AndreRussell          3      3
# DavidMiller           3      3
# DavidWarner           3      3
# DeepakHooda           3      3
# DevduttPadikkal       3      3
# DineshKarthik         3      3
# FafduPlessis          3      3
# GlennMaxwell          3      3
# HardikPandya          3      3
# IshanKishan           3      3
# JosButtler            3      3
# KLRahul               3      3
# KrunalPandya          3      3
# MShahrukhKhan         3      3
# ManishPandey          3      3
# MarcusStoinis         3      3
# MayankAgarwal         3      3
# MoeenAli              3      3
# NicholasPooran        3      3
# NitishRana            3      3
# PrithviShaw           3      3
# QuintondeKock         3      3
# RahulTripathi         3      3
# RavindraJadeja        3      3
# RiyanParag            3      3
# RohitSharma           3      3
# RuturajGaikwad        3      3
# SanjuSamson           3      3
# ShikharDhawan         3      3
# ShimronHetmyer        3      3
# ShivamDube            3      3
# ShubmanGill           3      3
# SuryakumarYadav       3      3
# VenkateshIyer         3      3
# ViratKohli            3      3
# WriddhimanSaha        3      3
# YashasviJaiswal       3      3

# %%
eligble_batsman_all_3_season.index
# Out:
# Index(['AbhishekSharma', 'AidenMarkram', 'AmbatiRayudu', 'AndreRussell',
#        'DavidMiller', 'DavidWarner', 'DeepakHooda', 'DevduttPadikkal',
#        'DineshKarthik', 'FafduPlessis', 'GlennMaxwell', 'HardikPandya',
#        'IshanKishan', 'JosButtler', 'KLRahul', 'KrunalPandya', 'MShahrukhKhan',
#        'ManishPandey', 'MarcusStoinis', 'MayankAgarwal', 'MoeenAli',
#        'NicholasPooran', 'NitishRana', 'PrithviShaw', 'QuintondeKock',
#        'RahulTripathi', 'RavindraJadeja', 'RiyanParag', 'RohitSharma',
#        'RuturajGaikwad', 'SanjuSamson', 'ShikharDhawan', 'ShimronHetmyer',
#        'ShivamDube', 'ShubmanGill', 'SuryakumarYadav', 'VenkateshIyer',
#        'ViratKohli', 'WriddhimanSaha', 'YashasviJaiswal'],
#       dtype='object', name='batsmanName')

# %%
df_bating_eligible = df_bating_merged_season[df_bating_merged_season["batsmanName"].isin(eligble_batsman_all_3_season.index)]

df_bating_eligible.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
# 5  T203817  Super Kings Vs KKR          KKR           2   VenkateshIyer
#
#   out/not_out  runs  balls  4s  6s  ...    battingStyle        bowlingStyle  \
# 0         out    32     27   3   1  ...  Right hand Bat  Right arm Offbreak
# 1         out    86     59   7   3  ...  Right hand Bat            Legbreak
# 3     not_out    37     20   2   3  ...   Left hand Bat  Right arm Offbreak
# 4         out    51     43   6   0  ...  Right hand Bat  Right arm Offbreak
# 5         out    50     32   5   3  ...   Left hand Bat    Right arm Medium
#
#            playingRole outs        team1  team2       winner   margin  \
# 0               Batter    1  Super Kings    KKR  Super Kings  27 runs
# 1  Middle order Batter    1  Super Kings    KKR  Super Kings  27 runs
# 3   Batting Allrounder    0  Super Kings    KKR  Super Kings  27 runs
# 4       Opening Batter    1  Super Kings    KKR  Super Kings  27 runs
# 5           Allrounder    1  Super Kings    KKR  Super Kings  27 runs
#
#    matchDate    season
# 0 2021-10-15  Season 1
# 1 2021-10-15  Season 1
# 3 2021-10-15  Season 1
# 4 2021-10-15  Season 1
# 5 2021-10-15  Season 1
#
# [5 rows x 22 columns]

# %%
df_batsman_average = df_bating_eligible.groupby("batsmanName").apply(lambda x: x["runs"].sum() / x["outs"].sum())

df_batsman_average
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_19636\964054876.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_batsman_average = df_bating_eligible.groupby("batsmanName").apply(lambda x: x["runs"].sum() / x["outs"].sum())
# batsmanName
# AbhishekSharma     24.833333
# AidenMarkram       32.291667
# AmbatiRayudu       22.225806
# AndreRussell       27.592593
# DavidMiller        43.200000
# DavidWarner        37.900000
# DeepakHooda        19.857143
# DevduttPadikkal    26.200000
# DineshKarthik      24.750000
# FafduPlessis       43.595238
# GlennMaxwell       34.685714
# HardikPandya       30.967742
# IshanKishan        30.081081
# JosButtler         41.916667
# KLRahul            50.533333
# KrunalPandya       17.724138
# MShahrukhKhan      20.285714
# ManishPandey       25.714286
# MarcusStoinis      26.875000
# MayankAgarwal      27.484848
# MoeenAli           23.387097
# NicholasPooran     24.300000
# NitishRana         29.666667
# PrithviShaw        25.468750
# QuintondeKock      33.857143
# RahulTripathi      28.500000
# RavindraJadeja     31.352941
# RiyanParag         14.160000
# RohitSharma        22.813953
# RuturajGaikwad     37.928571
# SanjuSamson        32.600000
# ShikharDhawan      39.771429
# ShimronHetmyer     40.666667
# ShivamDube         32.310345
# ShubmanGill        40.239130
# SuryakumarYadav    35.000000
# VenkateshIyer      28.117647
# ViratKohli         33.780488
# WriddhimanSaha     23.400000
# YashasviJaiswal    34.303030
# dtype: float64

# %%
df_batsman_average = df_batsman_average.sort_values(ascending=False).head(10)
df_batsman_average
# Out:
# batsmanName
# KLRahul            50.533333
# FafduPlessis       43.595238
# DavidMiller        43.200000
# JosButtler         41.916667
# ShimronHetmyer     40.666667
# ShubmanGill        40.239130
# ShikharDhawan      39.771429
# RuturajGaikwad     37.928571
# DavidWarner        37.900000
# SuryakumarYadav    35.000000
# dtype: float64

# %%
df_batsman_average.plot(kind="bar", color="green")
plt.title("Top 10 batsmen based on past 3 years batting average. (min 60 balls faced in each season)",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("average", fontsize="10", fontweight="bold")
plt.xlabel("Batsman Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style="whitegrid")

# Prepare data (if df_batsman_average has batsman names as index)
df_avg = df_batsman_average.reset_index()
df_avg.columns = ['Batsman', 'Average']

# Sort for better visualization (optional, if not already sorted)
df_avg = df_avg.sort_values(by="Average", ascending=False)

# Plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    data=df_avg,
    x='Batsman',
    y='Average',
    color='green',
    edgecolor='black'
)

# Titles and axis labels
plt.title("Top 10 Batsmen by Batting Average Over the Past 3 Years\n(Minimum 60 Balls Faced Per Season)",
          fontsize=12, fontweight="bold", pad=15)
plt.xlabel("Batsman", fontsize=11, fontweight="bold")
plt.ylabel("Batting Average", fontsize=11, fontweight="bold")

# X and Y ticks
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# Add data labels above bars
for index, row in df_avg.iterrows():
    plt.text(x=index, y=row['Average'] + 0.5, s=f"{row['Average']:.1f}",
             ha='center', va='bottom', fontsize=9, fontweight='semibold')

# Improve layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Top 10 batsmen based on past 3 years strike rate (min 60 balls faced in each season)

# %%
df_bating_eligible[["batsmanName","SR"]] .head()
# Out:
#       batsmanName      SR
# 0  RuturajGaikwad  118.51
# 1    FafduPlessis  145.76
# 3        MoeenAli  185.00
# 4     ShubmanGill  118.60
# 5   VenkateshIyer  156.25

# %%
df_batsman_SR = df_bating_eligible.groupby("batsmanName")["SR"].mean().sort_values(ascending=False).head(10)

df_batsman_SR
# Out:
# batsmanName
# GlennMaxwell       150.498780
# RavindraJadeja     139.281176
# ShimronHetmyer     139.144000
# SuryakumarYadav    138.758947
# MShahrukhKhan      133.760645
# DineshKarthik      133.450909
# RahulTripathi      131.458837
# YashasviJaiswal    127.891471
# ShivamDube         127.700882
# AndreRussell       126.324857
# Name: SR, dtype: float64

# %%
df_bating_eligible.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
# 5  T203817  Super Kings Vs KKR          KKR           2   VenkateshIyer
#
#   out/not_out  runs  balls  4s  6s  ...    battingStyle        bowlingStyle  \
# 0         out    32     27   3   1  ...  Right hand Bat  Right arm Offbreak
# 1         out    86     59   7   3  ...  Right hand Bat            Legbreak
# 3     not_out    37     20   2   3  ...   Left hand Bat  Right arm Offbreak
# 4         out    51     43   6   0  ...  Right hand Bat  Right arm Offbreak
# 5         out    50     32   5   3  ...   Left hand Bat    Right arm Medium
#
#            playingRole outs        team1  team2       winner   margin  \
# 0               Batter    1  Super Kings    KKR  Super Kings  27 runs
# 1  Middle order Batter    1  Super Kings    KKR  Super Kings  27 runs
# 3   Batting Allrounder    0  Super Kings    KKR  Super Kings  27 runs
# 4       Opening Batter    1  Super Kings    KKR  Super Kings  27 runs
# 5           Allrounder    1  Super Kings    KKR  Super Kings  27 runs
#
#    matchDate    season
# 0 2021-10-15  Season 1
# 1 2021-10-15  Season 1
# 3 2021-10-15  Season 1
# 4 2021-10-15  Season 1
# 5 2021-10-15  Season 1
#
# [5 rows x 22 columns]

# %%
df_batsman_SR_formula = df_bating_eligible.groupby("batsmanName").apply(lambda x: (x["runs"].sum() / x["balls"].sum()) * 100).sort_values(ascending=False).head(10)
df_batsman_SR_formula
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_19636\3809711221.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_batsman_SR_formula = df_bating_eligible.groupby("batsmanName").apply(lambda x: (x["runs"].sum() / x["balls"].sum()) * 100).sort_values(ascending=False).head(10)
# batsmanName
# GlennMaxwell       161.436170
# SuryakumarYadav    160.550459
# AndreRussell       159.188034
# ShimronHetmyer     157.274401
# NicholasPooran     157.112069
# PrithviShaw        153.195489
# DineshKarthik      152.643172
# YashasviJaiswal    152.150538
# JosButtler         146.932814
# ShivamDube         145.950156
# dtype: float64

# %%
df_batsman_SR_formula.plot(kind="bar", color="purple")
plt.title("Top 10 batsmen based on past 3 years Strike Rate. (min 60 balls faced in each season)",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("SR", fontsize="10", fontweight="bold")
plt.xlabel("Batsman Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style="whitegrid")

# Assuming df_batsman_SR_formula is a DataFrame with 'Batsman' and 'SR' columns
# If not, you can reset the index and rename columns accordingly
df_plot = df_batsman_SR_formula.reset_index()
df_plot.columns = ['Batsman', 'SR']

# Plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    data=df_plot,
    x='Batsman',
    y='SR',
    color="#6a0dad",
    edgecolor='black'
)

# Titles and labels
plt.title("Top 10 Batsmen by Strike Rate Over the Past 3 Years\n(Minimum 60 Balls Faced Per Season)",
          fontsize=12, fontweight="bold", pad=15)
plt.xlabel("Batsman", fontsize=11, fontweight="bold")
plt.ylabel("Strike Rate (SR)", fontsize=11, fontweight="bold")

# X-ticks
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# Add data labels on bars
for index, row in df_plot.iterrows():
    plt.text(x=index, y=row['SR'] + 1, s=f"{row['SR']:.1f}", 
             ha='center', va='bottom', fontsize=9, fontweight='semibold')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Top 10 bowlers based on past 3 years total wickets taken.

# %%
df_bowling.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls
# 0    33        0     11.0   6   2   3      0        0
# 1    32        1      8.0   8   1   2      0        0
# 2    56        0     14.0   4   7   2      2        0
# 3    38        0      9.5   5   2   2      0        1
# 4    26        2      6.5   6   0   1      1        0

# %%
df_bowling_top_wickets =df_bowling.groupby("bowlerName")["wickets"].sum().sort_values(ascending=False).head(10)
df_bowling_top_wickets
# Out:
# bowlerName
# MohammedShami        67
# YuzvendraChahal      66
# HarshalPatel         65
# RashidKhan           63
# AveshKhan            47
# ArshdeepSingh        45
# KagisoRabada         45
# VarunChakravarthy    44
# ShardulThakur        43
# TrentBoult           42
# Name: wickets, dtype: int64

# %%
df_bowling_top_wickets.plot(kind="bar", color=["violet","indigo","blue","green","yellow","orange","red"])
plt.title("Top 10 bowlers based on past 3 years total wickets taken.",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Wickets", fontsize="10", fontweight="bold")
plt.xlabel("Bowler Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 5. Top 10 bowlers based on past 3 years bowling average. (min 60 balls bowled in each season)

# %%
df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls team    battingStyle  \
# 0    33        0     11.0   6   2   3      0        0  KKR   Left hand Bat
# 1    32        1      8.0   8   1   2      0        0  KKR  Right hand Bat
# 2    56        0     14.0   4   7   2      2        0  KKR  Right hand Bat
# 3    38        0      9.5   5   2   2      0        1  KKR  Right hand Bat
# 4    26        2      6.5   6   0   1      1        0  KKR   Left hand Bat
#
#              bowlingStyle         playingRole
# 0  Slow Left arm Orthodox          Allrounder
# 1   Right arm Fast medium              Bowler
# 2          Right arm Fast              Bowler
# 3         Legbreak Googly              Bowler
# 4      Right arm Offbreak  Bowling Allrounder

# %%
df_bowling_merged["full_overs"] = df_bowling_merged["overs"].astype(int)

df_bowling_merged["extra_balls"] = (df_bowling_merged["overs"]-df_bowling_merged["full_overs"])*10

df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls team    battingStyle  \
# 0    33        0     11.0   6   2   3      0        0  KKR   Left hand Bat
# 1    32        1      8.0   8   1   2      0        0  KKR  Right hand Bat
# 2    56        0     14.0   4   7   2      2        0  KKR  Right hand Bat
# 3    38        0      9.5   5   2   2      0        1  KKR  Right hand Bat
# 4    26        2      6.5   6   0   1      1        0  KKR   Left hand Bat
#
#              bowlingStyle         playingRole  full_overs  extra_balls
# 0  Slow Left arm Orthodox          Allrounder           3          0.0
# 1   Right arm Fast medium              Bowler           4          0.0
# 2          Right arm Fast              Bowler           4          0.0
# 3         Legbreak Googly              Bowler           4          0.0
# 4      Right arm Offbreak  Bowling Allrounder           4          0.0

# %%
df_bowling_merged[df_bowling_merged["extra_balls"] > 0].head()
# Out:
#     match_id                    match bowlingTeam          bowlerName  overs  \
# 17   T206442          Capitals Vs KKR    Capitals  RavichandranAshwin    3.5
# 31   T208597               RCB Vs KKR         RCB        DanChristian    1.4
# 42   T201819  Capitals Vs Super Kings    Capitals           TomCurran    3.4
# 76   T204179            KKR Vs Royals         KKR          ShivamMavi    3.1
# 108  T205599         Royals Vs Mumbai      Royals    MustafizurRahman    2.2
#
#      maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls      team  \
# 17        0    27        2     7.04   7   1   1      1        0  Capitals
# 31        0    29        0    17.40   1   1   3      2        0       RCB
# 42        0    29        3     7.90   6   3   0      2        0  Capitals
# 76        0    21        4     6.63  10   3   0      0        0       KKR
# 108       0    32        1    13.71   6   3   2      1        0    Royals
#
#        battingStyle           bowlingStyle         playingRole  full_overs  \
# 17   Right hand Bat     Right arm Offbreak  Bowling Allrounder           3
# 31   Right hand Bat  Right arm Fast medium          Allrounder           1
# 42   Right hand Bat  Right arm Fast medium  Bowling Allrounder           3
# 76   Right hand Bat  Right arm Fast medium              Bowler           3
# 108   Left hand Bat   Left arm Fast medium              Bowler           2
#
#      extra_balls
# 17           5.0
# 31           4.0
# 42           4.0
# 76           1.0
# 108          2.0

# %%
df_bowling_merged["total_balls"] = df_bowling_merged["full_overs"] * 6 + df_bowling_merged["extra_balls"]
df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  ...  6s  wides  noBalls  team    battingStyle  \
# 0    33        0     11.0   6  ...   3      0        0   KKR   Left hand Bat
# 1    32        1      8.0   8  ...   2      0        0   KKR  Right hand Bat
# 2    56        0     14.0   4  ...   2      2        0   KKR  Right hand Bat
# 3    38        0      9.5   5  ...   2      0        1   KKR  Right hand Bat
# 4    26        2      6.5   6  ...   1      1        0   KKR   Left hand Bat
#
#              bowlingStyle         playingRole full_overs  extra_balls  \
# 0  Slow Left arm Orthodox          Allrounder          3          0.0
# 1   Right arm Fast medium              Bowler          4          0.0
# 2          Right arm Fast              Bowler          4          0.0
# 3         Legbreak Googly              Bowler          4          0.0
# 4      Right arm Offbreak  Bowling Allrounder          4          0.0
#
#    total_balls
# 0         18.0
# 1         24.0
# 2         24.0
# 3         24.0
# 4         24.0
#
# [5 rows x 21 columns]

# %%
df_bowling_merged.drop(columns=["full_overs","extra_balls"], inplace=True)df_bowling_merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 df_bowling_merged.drop(columns=["full_overs","extra_balls"], inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['full_overs', 'extra_balls'] not found in axis"

# %%
df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls team    battingStyle  \
# 0    33        0     11.0   6   2   3      0        0  KKR   Left hand Bat
# 1    32        1      8.0   8   1   2      0        0  KKR  Right hand Bat
# 2    56        0     14.0   4   7   2      2        0  KKR  Right hand Bat
# 3    38        0      9.5   5   2   2      0        1  KKR  Right hand Bat
# 4    26        2      6.5   6   0   1      1        0  KKR   Left hand Bat
#
#              bowlingStyle         playingRole  total_balls
# 0  Slow Left arm Orthodox          Allrounder         18.0
# 1   Right arm Fast medium              Bowler         24.0
# 2          Right arm Fast              Bowler         24.0
# 3         Legbreak Googly              Bowler         24.0
# 4      Right arm Offbreak  Bowling Allrounder         24.0

# %%
df_match.head()
# Out:
#          team1        team2       winner     margin  matchDate match_id  \
# 0  Super Kings          KKR  Super Kings    27 runs 2021-10-15  T203817
# 1     Capitals          KKR          KKR  3 wickets 2021-10-13  T206442
# 2          RCB          KKR          KKR  4 wickets 2021-10-11  T208597
# 3     Capitals  Super Kings  Super Kings  4 wickets 2021-10-10  T201819
# 4     Capitals          RCB          RCB  7 wickets 2021-10-08  T205942
#
#      season
# 0  Season 1
# 1  Season 1
# 2  Season 1
# 3  Season 1
# 4  Season 1

# %%
df_bowling_merged_season = df_bowling_merged.merge(df_match, on="match_id")

df_bowling_merged_season.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  ...    battingStyle            bowlingStyle  \
# 0    33        0     11.0   6  ...   Left hand Bat  Slow Left arm Orthodox
# 1    32        1      8.0   8  ...  Right hand Bat   Right arm Fast medium
# 2    56        0     14.0   4  ...  Right hand Bat          Right arm Fast
# 3    38        0      9.5   5  ...  Right hand Bat         Legbreak Googly
# 4    26        2      6.5   6  ...   Left hand Bat      Right arm Offbreak
#
#           playingRole  total_balls        team1 team2       winner   margin  \
# 0          Allrounder         18.0  Super Kings   KKR  Super Kings  27 runs
# 1              Bowler         24.0  Super Kings   KKR  Super Kings  27 runs
# 2              Bowler         24.0  Super Kings   KKR  Super Kings  27 runs
# 3              Bowler         24.0  Super Kings   KKR  Super Kings  27 runs
# 4  Bowling Allrounder         24.0  Super Kings   KKR  Super Kings  27 runs
#
#    matchDate    season
# 0 2021-10-15  Season 1
# 1 2021-10-15  Season 1
# 2 2021-10-15  Season 1
# 3 2021-10-15  Season 1
# 4 2021-10-15  Season 1
#
# [5 rows x 25 columns]

# %%
df_bowling_eligible = df_bowling_merged_season.groupby(["bowlerName","season"])["total_balls"].sum().reset_index()

df_bowling_eligible
# Out:
#           bowlerName    season  total_balls
# 0         AbdulSamad  Season 1          6.0
# 1         AbdulSamad  Season 2          6.0
# 2     AbhishekSharma  Season 1         54.0
# 3     AbhishekSharma  Season 2         24.0
# 4     AbhishekSharma  Season 3         72.0
# ..               ...       ...          ...
# 366  YashasviJaiswal  Season 2          1.0
# 367     YudhvirSingh  Season 3         48.0
# 368  YuzvendraChahal  Season 1        318.0
# 369  YuzvendraChahal  Season 2        408.0
# 370  YuzvendraChahal  Season 3        317.0
#
# [371 rows x 3 columns]

# %%
df_bowling_eligible =  df_bowling_eligible[df_bowling_eligible["total_balls"] >= 60]

df_bowling_eligible
# Out:
#           bowlerName    season  total_balls
# 4     AbhishekSharma  Season 3         72.0
# 5          AdamMilne  Season 1         84.0
# 7          AdamZampa  Season 3        132.0
# 13         AkashDeep  Season 2        113.0
# 15      AkashMadhwal  Season 3        153.0
# ..               ...       ...          ...
# 364        YashDayal  Season 3         84.0
# 365       YashThakur  Season 3        191.0
# 368  YuzvendraChahal  Season 1        318.0
# 369  YuzvendraChahal  Season 2        408.0
# 370  YuzvendraChahal  Season 3        317.0
#
# [234 rows x 3 columns]

# %%
df_bowling_eligible =  df_bowling_eligible.groupby("bowlerName").count()
df_bowling_eligible
# Out:
#                   season  total_balls
# bowlerName
# AbhishekSharma         1            1
# AdamMilne              1            1
# AdamZampa              1            1
# AkashDeep              1            1
# AkashMadhwal           1            1
# ...                  ...          ...
# WashingtonSundar       3            3
# WayneParnell           1            1
# YashDayal              2            2
# YashThakur             1            1
# YuzvendraChahal        3            3
#
# [132 rows x 2 columns]

# %%
df_bowling_eligible = df_bowling_eligible[df_bowling_eligible.season == 3]

df_bowling_eligible.index
# Out:
# Index(['AndreRussell', 'AnrichNortje', 'ArshdeepSingh', 'AveshKhan',
#        'AxarPatel', 'BhuvneshwarKumar', 'ChrisJordan', 'GlennMaxwell',
#        'HarpreetBrar', 'HarshalPatel', 'JasonHolder', 'KagisoRabada',
#        'KhaleelAhmed', 'KrunalPandya', 'LalitYadav', 'MoeenAli',
#        'MohammedShami', 'MohammedSiraj', 'RahulChahar', 'RashidKhan',
#        'RaviBishnoi', 'RavichandranAshwin', 'RavindraJadeja', 'RileyMeredith',
#        'SandeepSharma', 'ShardulThakur', 'SunilNarine', 'TrentBoult',
#        'UmranMalik', 'VarunChakravarthy', 'WashingtonSundar',
#        'YuzvendraChahal'],
#       dtype='object', name='bowlerName')

# %%
df_bowling_player_eligible =  df_bowling_merged[df_bowling_merged.bowlerName.isin(df_bowling_eligible.index)]

df_bowling_player_eligible.head()
# Out:
#    match_id               match  bowlingTeam         bowlerName  overs  \
# 3   T203817  Super Kings Vs KKR          KKR  VarunChakravarthy    4.0
# 4   T203817  Super Kings Vs KKR          KKR        SunilNarine    4.0
# 8   T203817  Super Kings Vs KKR  Super Kings      ShardulThakur    4.0
# 10  T203817  Super Kings Vs KKR  Super Kings     RavindraJadeja    4.0
# 13  T206442     Capitals Vs KKR          KKR        SunilNarine    4.0
#
#     maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls         team  \
# 3        0    38        0     9.50   5   2   2      0        1          KKR
# 4        0    26        2     6.50   6   0   1      1        0          KKR
# 8        0    38        3     9.50  11   3   1      4        1  Super Kings
# 10       0    37        2     9.25   9   3   2      1        0  Super Kings
# 13       0    27        0     6.75   9   0   2      1        0          KKR
#
#       battingStyle            bowlingStyle         playingRole  total_balls
# 3   Right hand Bat         Legbreak Googly              Bowler         24.0
# 4    Left hand Bat      Right arm Offbreak  Bowling Allrounder         24.0
# 8   Right hand Bat        Right arm Medium              Bowler         24.0
# 10   Left hand Bat  Slow Left arm Orthodox          Allrounder         24.0
# 13   Left hand Bat      Right arm Offbreak  Bowling Allrounder         24.0

# %%
df_bowling_average =df_bowling_player_eligible.groupby("bowlerName").apply(lambda x : x["runs"].sum()/x["wickets"].sum()).round(2).sort_values().head(10)
df_bowling_average
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_19636\3640025843.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_bowling_average =df_bowling_player_eligible.groupby("bowlerName").apply(lambda x : x["runs"].sum()/x["wickets"].sum()).round(2).sort_values().head(10)
# bowlerName
# AndreRussell       18.23
# YuzvendraChahal    20.20
# HarshalPatel       20.35
# RashidKhan         20.90
# MohammedShami      20.97
# AveshKhan          23.72
# KagisoRabada       23.76
# MoeenAli           23.86
# AnrichNortje       24.77
# UmranMalik         26.10
# dtype: float64

# %%
df_bowling_average.plot(kind="bar")
plt.title("Top 10 bowlers based on past 3 years bowling average. (min 60 balls faced in each season)",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Bowling Average", fontsize="10", fontweight="bold")
plt.xlabel("Bowlers Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 6. Top 10 bowlers based on past 3 years economy rate. (min 60 balls bowled in each season)

# %%
df_bowling_eco_rate =df_bowling_player_eligible.groupby("bowlerName").apply(lambda x : x["runs"].sum()/x["overs"].sum()).round(2).sort_values().head(10)
df_bowling_eco_rate
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_19636\252630166.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_bowling_eco_rate =df_bowling_player_eligible.groupby("bowlerName").apply(lambda x : x["runs"].sum()/x["overs"].sum()).round(2).sort_values().head(10)
# bowlerName
# SunilNarine           6.60
# MoeenAli              7.09
# AxarPatel             7.11
# RashidKhan            7.22
# KrunalPandya          7.45
# RavindraJadeja        7.46
# RavichandranAshwin    7.53
# VarunChakravarthy     7.58
# HarpreetBrar          7.61
# RahulChahar           7.68
# dtype: float64

# %%
df_bowling_eco_rate.plot(kind="bar")
plt.title("Top 10 bowlers based on past 3 years economic rate. (min 60 balls faced in each season)",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Economy Rate", fontsize="10", fontweight="bold")
plt.xlabel("Bowlers Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 7. Top 5 batsmen based on past 3 years boundary % (fours and sixes).

# %%
df_boundary = df_bating.copy()

df_boundary.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76
# 2         out    31     15   0   3  206.66
# 3     not_out    37     20   2   3  185.00
# 4         out    51     43   6   0  118.60

# %%
df_boundary["boundary_runs"] = df_boundary["4s"] * 4 + df_boundary["6s"]*6

df_boundary.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR  boundary_runs
# 0         out    32     27   3   1  118.51             18
# 1         out    86     59   7   3  145.76             46
# 2         out    31     15   0   3  206.66             18
# 3     not_out    37     20   2   3  185.00             26
# 4         out    51     43   6   0  118.60             24

# %%
df_boundary["boudary_pct"] = round((df_boundary["boundary_runs"] / df_boundary["runs"]) * 100,2);

df_boundary.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR  boundary_runs  boudary_pct
# 0         out    32     27   3   1  118.51             18        56.25
# 1         out    86     59   7   3  145.76             46        53.49
# 2         out    31     15   0   3  206.66             18        58.06
# 3     not_out    37     20   2   3  185.00             26        70.27
# 4         out    51     43   6   0  118.60             24        47.06

# %%
top_boundary = df_boundary.groupby("batsmanName")["boudary_pct"].mean().sort_values(ascending = False).head(5)
top_boundary
# Out:
# batsmanName
# AbhijeetTomar        100.000
# LittonDas            100.000
# SanvirSingh           92.855
# ShreyasGopal          87.300
# MaheeshTheekshana     85.710
# Name: boudary_pct, dtype: float64

# %%
top_boundary.plot(kind="bar", color="orange")
plt.title("Top 5 batsmen based on past 3 years boundary % (fours and sixes).",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Boundary Percentage %", fontsize="10", fontweight="bold")
plt.xlabel("Batsman Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 8. Top 5 bowlers based on past 3 years dot ball %.

# %%
df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls team    battingStyle  \
# 0    33        0     11.0   6   2   3      0        0  KKR   Left hand Bat
# 1    32        1      8.0   8   1   2      0        0  KKR  Right hand Bat
# 2    56        0     14.0   4   7   2      2        0  KKR  Right hand Bat
# 3    38        0      9.5   5   2   2      0        1  KKR  Right hand Bat
# 4    26        2      6.5   6   0   1      1        0  KKR   Left hand Bat
#
#              bowlingStyle         playingRole  total_balls
# 0  Slow Left arm Orthodox          Allrounder         18.0
# 1   Right arm Fast medium              Bowler         24.0
# 2          Right arm Fast              Bowler         24.0
# 3         Legbreak Googly              Bowler         24.0
# 4      Right arm Offbreak  Bowling Allrounder         24.0

# %%
df_bowling_merged["dot_pct"] = round((df_bowling_merged["0s"] / df_bowling_merged["total_balls"]) * 100,2)
df_bowling_merged.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls team    battingStyle  \
# 0    33        0     11.0   6   2   3      0        0  KKR   Left hand Bat
# 1    32        1      8.0   8   1   2      0        0  KKR  Right hand Bat
# 2    56        0     14.0   4   7   2      2        0  KKR  Right hand Bat
# 3    38        0      9.5   5   2   2      0        1  KKR  Right hand Bat
# 4    26        2      6.5   6   0   1      1        0  KKR   Left hand Bat
#
#              bowlingStyle         playingRole  total_balls  dot_pct
# 0  Slow Left arm Orthodox          Allrounder         18.0    33.33
# 1   Right arm Fast medium              Bowler         24.0    33.33
# 2          Right arm Fast              Bowler         24.0    16.67
# 3         Legbreak Googly              Bowler         24.0    20.83
# 4      Right arm Offbreak  Bowling Allrounder         24.0    25.00

# %%
top_dots = df_bowling_merged.groupby("bowlerName")["dot_pct"].mean().sort_values(ascending = False).head(5)
top_dots
# Out:
# bowlerName
# ShreyasIyer     66.670000
# ImranTahir      58.330000
# ReeceTopley     58.330000
# AyushBadoni     55.556667
# YudhvirSingh    51.850000
# Name: dot_pct, dtype: float64

# %%
top_dots.plot(kind="bar", color="teal")
plt.title("Top 5 bowlers based on past 3 years dot ball %.",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Dot Ball Percentage %", fontsize="10", fontweight="bold")
plt.xlabel("Bowlers Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 9. Top 4 teams based on past 3 years winning %.
# `

# %%
df_match
# Out:
#             team1        team2        winner     margin  matchDate match_id  \
# 0     Super Kings          KKR   Super Kings    27 runs 2021-10-15  T203817
# 1        Capitals          KKR           KKR  3 wickets 2021-10-13  T206442
# 2             RCB          KKR           KKR  4 wickets 2021-10-11  T208597
# 3        Capitals  Super Kings   Super Kings  4 wickets 2021-10-10  T201819
# 4        Capitals          RCB           RCB  7 wickets 2021-10-08  T205942
# ..            ...          ...           ...        ...        ...      ...
# 201        Mumbai          RCB           RCB  8 wickets 2023-04-02  T202485
# 202        Royals    Sunrisers        Royals    72 runs 2023-04-02  T209117
# 203  Super Giants     Capitals  Super Giants    50 runs 2023-04-01  T208512
# 204  Punjab Kings          KKR  Punjab Kings     7 runs 2023-04-01  T202853
# 205   Super Kings       Titans        Titans  5 wickets 2023-03-31  T201566
#
#        season
# 0    Season 1
# 1    Season 1
# 2    Season 1
# 3    Season 1
# 4    Season 1
# ..        ...
# 201  Season 3
# 202  Season 3
# 203  Season 3
# 204  Season 3
# 205  Season 3
#
# [206 rows x 7 columns]

# %%
match_count = pd.concat([df_match["team1"], df_match["team2"]])
match_count
# Out:
# 0      Super Kings
# 1         Capitals
# 2              RCB
# 3         Capitals
# 4         Capitals
#           ...
# 201            RCB
# 202      Sunrisers
# 203       Capitals
# 204            KKR
# 205         Titans
# Length: 412, dtype: object

# %%
match_count = match_count.value_counts()
match_count
# Out:
# Super Kings     45
# RCB             45
# Royals          45
# KKR             45
# Mumbai          44
# Capitals        43
# Punjab Kings    42
# Sunrisers       41
# Titans          33
# Super Giants    29
# Name: count, dtype: int64

# %%
win_count = df_match["winner"].value_counts()
win_count
# Out:
# winner
# Super Kings     25
# RCB             25
# Titans          23
# Royals          22
# KKR             21
# Capitals        21
# Mumbai          20
# Punjab Kings    19
# Super Giants    17
# Sunrisers       13
# Name: count, dtype: int64

# %%
win_pct = round((win_count/match_count)*100,2)
win_pct
# Out:
# Capitals        48.84
# KKR             46.67
# Mumbai          45.45
# Punjab Kings    45.24
# RCB             55.56
# Royals          48.89
# Sunrisers       31.71
# Super Giants    58.62
# Super Kings     55.56
# Titans          69.70
# Name: count, dtype: float64

# %%
top_teams = win_pct.sort_values(ascending=False).head(4)
top_teams
# Out:
# Titans          69.70
# Super Giants    58.62
# RCB             55.56
# Super Kings     55.56
# Name: count, dtype: float64

# %%
top_teams.plot(kind="bar", color="gray")
plt.title("Top 4 teams based on winning percentage%.",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Win Percentage %", fontsize="10", fontweight="bold")
plt.xlabel("Team Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 10.Top 2 teams with the highest number of wins achieved by chasing targets over the past 3 years.

# %%
df_match.head()
# Out:
#          team1        team2       winner     margin  matchDate match_id  \
# 0  Super Kings          KKR  Super Kings    27 runs 2021-10-15  T203817
# 1     Capitals          KKR          KKR  3 wickets 2021-10-13  T206442
# 2          RCB          KKR          KKR  4 wickets 2021-10-11  T208597
# 3     Capitals  Super Kings  Super Kings  4 wickets 2021-10-10  T201819
# 4     Capitals          RCB          RCB  7 wickets 2021-10-08  T205942
#
#      season
# 0  Season 1
# 1  Season 1
# 2  Season 1
# 3  Season 1
# 4  Season 1

# %%
chasing_win_teams = df_match[df_match["margin"].str.contains("wickets", case=False)]
chasing_win_teams
# Out:
#            team1         team2        winner     margin  matchDate match_id  \
# 1       Capitals           KKR           KKR  3 wickets 2021-10-13  T206442
# 2            RCB           KKR           KKR  4 wickets 2021-10-11  T208597
# 3       Capitals   Super Kings   Super Kings  4 wickets 2021-10-10  T201819
# 4       Capitals           RCB           RCB  7 wickets 2021-10-08  T205942
# 7    Super Kings  Punjab Kings  Punjab Kings  6 wickets 2021-10-07  T201866
# ..           ...           ...           ...        ...        ...      ...
# 194       Mumbai   Super Kings   Super Kings  7 wickets 2023-04-08  T206408
# 196    Sunrisers  Super Giants  Super Giants  5 wickets 2023-04-07  T209590
# 199     Capitals        Titans        Titans  6 wickets 2023-04-04  T205026
# 201       Mumbai           RCB           RCB  8 wickets 2023-04-02  T202485
# 205  Super Kings        Titans        Titans  5 wickets 2023-03-31  T201566
#
#        season
# 1    Season 1
# 2    Season 1
# 3    Season 1
# 4    Season 1
# 7    Season 1
# ..        ...
# 194  Season 3
# 196  Season 3
# 199  Season 3
# 201  Season 3
# 205  Season 3
#
# [106 rows x 7 columns]

# %%
top_chasing_teams = chasing_win_teams["winner"].value_counts().sort_values(ascending=False)

# %%
top_chasing_teams
# Out:
# winner
# KKR             14
# Capitals        14
# Titans          14
# Mumbai          13
# Super Kings     11
# RCB             10
# Sunrisers        9
# Royals           9
# Punjab Kings     8
# Super Giants     4
# Name: count, dtype: int64

# %%
top_chasing_teams = top_chasing_teams.head(2)
top_chasing_teams
# Out:
# winner
# KKR         14
# Capitals    14
# Name: count, dtype: int64

# %%
top_chasing_teams.plot(kind="bar", color=["skyblue","orange"])
plt.title("Top 2 with the highest number of wins achieved by chasing targets over the past 3 years.",fontsize="10", fontweight="bold")

plt.grid(linestyle='--', alpha=0.5)
plt.ylabel("Wins while Chasing", fontsize="10", fontweight="bold")
plt.xlabel("Team Name", fontsize="10", fontweight="bold")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # _____________________________________________________________________________________

# %% [markdown]
# # 4. Insight Generation (SECONDARY)
# `

# %% [markdown]
# # _____________________________________________________________________________________

# %% [markdown]
# ### Predict the following for the season 2024 using available data and by doing additional research

# %% [markdown]
# # 1. Orange and purple cap player

# %% [markdown]
# ##### Orange Cap -> Highest Run Scorer

# %%
df_bating.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76
# 2         out    31     15   0   3  206.66
# 3     not_out    37     20   2   3  185.00
# 4         out    51     43   6   0  118.60

# %%
df_orange_cap = df_bating.groupby("batsmanName")["runs"].sum().sort_values(ascending = False).head(5).reset_index()
df_orange_cap
# Out:
#       batsmanName  runs
# 0     ShubmanGill  1851
# 1    FafduPlessis  1831
# 2  RuturajGaikwad  1593
# 3         KLRahul  1516
# 4      JosButtler  1509

# %% [markdown]
# # Orange Cap Winner Is

# %%
df_orange_cap[["batsmanName"]].head(1)
# Out:
#    batsmanName
# 0  ShubmanGill

# %% [markdown]
# #### Purple Cap -> Highest Wicket Taker

# %%
df_bowling.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls
# 0    33        0     11.0   6   2   3      0        0
# 1    32        1      8.0   8   1   2      0        0
# 2    56        0     14.0   4   7   2      2        0
# 3    38        0      9.5   5   2   2      0        1
# 4    26        2      6.5   6   0   1      1        0

# %%
df_purple_cap = df_bowling.groupby("bowlerName")["wickets"].sum().sort_values(ascending = False).head(5).reset_index()
df_purple_cap
# Out:
#         bowlerName  wickets
# 0    MohammedShami       67
# 1  YuzvendraChahal       66
# 2     HarshalPatel       65
# 3       RashidKhan       63
# 4        AveshKhan       47

# %% [markdown]
# # Purple Cap Winner Is

# %%
df_purple_cap[["bowlerName"]].head(1)
# Out:
#       bowlerName
# 0  MohammedShami

# %% [markdown]
# ## 2. Top 4 qualifying teams

# %%
top_4_teams = win_pct.sort_values(ascending = False).head(4)
top_4_teams
# Out:
# Titans          69.70
# Super Giants    58.62
# RCB             55.56
# Super Kings     55.56
# Name: count, dtype: float64

# %%
print(f"Top 4 qualifying teams are: {list(top_4_teams.index)}")
# Out:
# Top 4 qualifying teams are: ['Titans', 'Super Giants', 'RCB', 'Super Kings']

# %% [markdown]
# ## 3. Winner and runner-up

# %%
chasing_win_teams
# Out:
#            team1         team2        winner     margin  matchDate match_id  \
# 1       Capitals           KKR           KKR  3 wickets 2021-10-13  T206442
# 2            RCB           KKR           KKR  4 wickets 2021-10-11  T208597
# 3       Capitals   Super Kings   Super Kings  4 wickets 2021-10-10  T201819
# 4       Capitals           RCB           RCB  7 wickets 2021-10-08  T205942
# 7    Super Kings  Punjab Kings  Punjab Kings  6 wickets 2021-10-07  T201866
# ..           ...           ...           ...        ...        ...      ...
# 194       Mumbai   Super Kings   Super Kings  7 wickets 2023-04-08  T206408
# 196    Sunrisers  Super Giants  Super Giants  5 wickets 2023-04-07  T209590
# 199     Capitals        Titans        Titans  6 wickets 2023-04-04  T205026
# 201       Mumbai           RCB           RCB  8 wickets 2023-04-02  T202485
# 205  Super Kings        Titans        Titans  5 wickets 2023-03-31  T201566
#
#        season
# 1    Season 1
# 2    Season 1
# 3    Season 1
# 4    Season 1
# 7    Season 1
# ..        ...
# 194  Season 3
# 196  Season 3
# 199  Season 3
# 201  Season 3
# 205  Season 3
#
# [106 rows x 7 columns]

# %%
chasing_win_teams_most_wins = chasing_win_teams["winner"].value_counts().sort_values(ascending=False)

chasing_win_teams_most_wins
# Out:
# winner
# KKR             14
# Capitals        14
# Titans          14
# Mumbai          13
# Super Kings     11
# RCB             10
# Sunrisers        9
# Royals           9
# Punjab Kings     8
# Super Giants     4
# Name: count, dtype: int64

# %%
print(f"Winner and Runner up is: {chasing_win_teams_most_wins.head(2).index}")
# Out:
# Winner and Runner up is: Index(['KKR', 'Capitals'], dtype='object', name='winner')

# %% [markdown]
# # 5. Pick your top 3 all-rounders

# %% [markdown]
# ## Approach: Players with atleast

# %% [markdown]
# * 200+ runs (across 3 years)

# %% [markdown]
# * 10+ wickets (across 3 years)

# %%
df_bating.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76
# 2         out    31     15   0   3  206.66
# 3     not_out    37     20   2   3  185.00
# 4         out    51     43   6   0  118.60

# %%
bat_sum = df_bating.groupby("batsmanName")["runs"].sum().reset_index()
bat_sum
# Out:
#          batsmanName  runs
# 0       ABdeVilliers   313
# 1         AaronFinch    86
# 2        AbdulBasith     1
# 3         AbdulSamad   284
# 4      AbhijeetTomar     4
# ..               ...   ...
# 259        YashDayal     0
# 260        YashDhull    16
# 261  YashasviJaiswal  1132
# 262     YudhvirSingh     1
# 263  YuzvendraChahal    15
#
# [264 rows x 2 columns]

# %%
df_bowling.head()
# Out:
#   match_id               match bowlingTeam         bowlerName  overs  maiden  \
# 0  T203817  Super Kings Vs KKR         KKR      ShakibAlHasan    3.0       0
# 1  T203817  Super Kings Vs KKR         KKR         ShivamMavi    4.0       0
# 2  T203817  Super Kings Vs KKR         KKR     LockieFerguson    4.0       0
# 3  T203817  Super Kings Vs KKR         KKR  VarunChakravarthy    4.0       0
# 4  T203817  Super Kings Vs KKR         KKR        SunilNarine    4.0       0
#
#    runs  wickets  economy  0s  4s  6s  wides  noBalls
# 0    33        0     11.0   6   2   3      0        0
# 1    32        1      8.0   8   1   2      0        0
# 2    56        0     14.0   4   7   2      2        0
# 3    38        0      9.5   5   2   2      0        1
# 4    26        2      6.5   6   0   1      1        0

# %%
bowl_sum = df_bowling.groupby("bowlerName")["wickets"].sum().reset_index()
bowl_sum
# Out:
#           bowlerName  wickets
# 0         AbdulSamad        1
# 1     AbhishekSharma        6
# 2          AdamMilne        3
# 3          AdamZampa        8
# 4         AdilRashid        2
# ..               ...      ...
# 197        YashDayal       13
# 198       YashThakur       13
# 199  YashasviJaiswal        0
# 200     YudhvirSingh        3
# 201  YuzvendraChahal       66
#
# [202 rows x 2 columns]

# %%
df_allrounders = pd.merge(bat_sum, bowl_sum, left_on="batsmanName",right_on="bowlerName")
df_allrounders
# Out:
#          batsmanName  runs       bowlerName  wickets
# 0         AbdulSamad   284       AbdulSamad        1
# 1     AbhishekSharma   745   AbhishekSharma        6
# 2          AdamMilne    16        AdamMilne        3
# 3          AdamZampa    10        AdamZampa        8
# 4         AdilRashid    22       AdilRashid        2
# ..               ...   ...              ...      ...
# 169     WayneParnell     2     WayneParnell        9
# 170        YashDayal     0        YashDayal       13
# 171  YashasviJaiswal  1132  YashasviJaiswal        0
# 172     YudhvirSingh     1     YudhvirSingh        3
# 173  YuzvendraChahal    15  YuzvendraChahal       66
#
# [174 rows x 4 columns]

# %%
df_allrounders_best =df_allrounders[(df_allrounders["runs"] >= 200) & (df_allrounders["wickets"] >= 10)]
df_allrounders_best
# Out:
#             batsmanName  runs          bowlerName  wickets
# 11         AndreRussell   745        AndreRussell       35
# 18            AxarPatel   505           AxarPatel       30
# 43         GlennMaxwell  1214        GlennMaxwell       12
# 46         HardikPandya   960        HardikPandya       11
# 71         KrunalPandya   514        KrunalPandya       24
# 78           LalitYadav   295          LalitYadav       10
# 84        MarcusStoinis   645       MarcusStoinis       11
# 89        MitchellMarsh   379       MitchellMarsh       16
# 91             MoeenAli   725            MoeenAli       21
# 120          RashidKhan   304          RashidKhan       63
# 123  RavichandranAshwin   302  RavichandranAshwin       33
# 124      RavindraJadeja   533      RavindraJadeja       37
# 132           SamCurran   332           SamCurran       19
# 136        ShahbazAhmed   320        ShahbazAhmed       12
# 139       ShardulThakur   238       ShardulThakur       43

# %%
top_3_allrounders = df_allrounders_best.sort_values(by=["runs","wickets"], ascending=False).head(3)
top_3_allrounders
# Out:
#      batsmanName  runs    bowlerName  wickets
# 43  GlennMaxwell  1214  GlennMaxwell       12
# 46  HardikPandya   960  HardikPandya       11
# 11  AndreRussell   745  AndreRussell       35

# %% [markdown]
# ## Top 3 All-Rounders for 2024

# %%
top_3_allrounders[["batsmanName","runs","wickets"]]
# Out:
#      batsmanName  runs  wickets
# 43  GlennMaxwell  1214       12
# 46  HardikPandya   960       11
# 11  AndreRussell   745       35

# %%
list(top_3_allrounders.batsmanName)
# Out:
# ['GlennMaxwell', 'HardikPandya', 'AndreRussell']

# %% [markdown]
# # 4. Pick your team selecting the Best 11 players based on their positions, 3 years performance data and additional research

# %% [markdown]
# #### Team Composition:

# %% [markdown]
# * 4 Batsman: Highest Total Runs Exclude Wicket Keeper
# * 1 Wicket Keeper: Among Highest Total Run Scorers
# * 3 Bowler: Highest Total Wickets
# * 3 All-Rounders: Players with 200+ runs & 10+ wickets

# %%
df_orange_cap.head(4)
# Out:
#       batsmanName  runs
# 0     ShubmanGill  1851
# 1    FafduPlessis  1831
# 2  RuturajGaikwad  1593
# 3         KLRahul  1516

# %%
df_purple_cap.head(3)
# Out:
#         bowlerName  wickets
# 0    MohammedShami       67
# 1  YuzvendraChahal       66
# 2     HarshalPatel       65

# %%
top_3_allrounders
# Out:
#      batsmanName  runs    bowlerName  wickets
# 43  GlennMaxwell  1214  GlennMaxwell       12
# 46  HardikPandya   960  HardikPandya       11
# 11  AndreRussell   745  AndreRussell       35

# %%
df_orange_cap = df_bating.groupby("batsmanName")["runs"].sum().sort_values(ascending = False).reset_index()
df_orange_cap.head(20)
# Out:
#         batsmanName  runs
# 0       ShubmanGill  1851
# 1      FafduPlessis  1831
# 2    RuturajGaikwad  1593
# 3           KLRahul  1516
# 4        JosButtler  1509
# 5     ShikharDhawan  1392
# 6        ViratKohli  1385
# 7       SanjuSamson  1304
# 8   SuryakumarYadav  1225
# 9      GlennMaxwell  1214
# 10       NitishRana  1157
# 11      DavidWarner  1137
# 12  YashasviJaiswal  1132
# 13      IshanKishan  1113
# 14    RahulTripathi  1083
# 15  DevduttPadikkal  1048
# 16      RohitSharma   981
# 17     HardikPandya   960
# 18    VenkateshIyer   956
# 19    QuintondeKock   948

# %%
df_players
# Out:
#                       name          team    battingStyle  \
# 0           RuturajGaikwad   Super Kings  Right hand Bat
# 1             FafduPlessis   Super Kings  Right hand Bat
# 2             RobinUthappa   Super Kings  Right hand Bat
# 3                 MoeenAli   Super Kings   Left hand Bat
# 4              ShubmanGill           KKR  Right hand Bat
# ..                     ...           ...             ...
# 287           AbishekPorel      Capitals   Left hand Bat
# 288          SisandaMagala   Super Kings  Right hand Bat
# 289            MohitRathee  Punjab Kings  Right hand Bat
# 290  RajvardhanHangargekar   Super Kings  Right hand Bat
# 291            ReeceTopley           RCB  Right hand Bat
#
#               bowlingStyle          playingRole
# 0       Right arm Offbreak               Batter
# 1                 Legbreak  Middle order Batter
# 2         Right arm Medium               Batter
# 3       Right arm Offbreak   Batting Allrounder
# 4       Right arm Offbreak       Opening Batter
# ..                     ...                  ...
# 287          Not Available  Wicketkeeper Batter
# 288  Right arm Fast medium               Bowler
# 289               Legbreak           Allrounder
# 290  Right arm Fast medium   Bowling Allrounder
# 291   Left arm Fast medium               Bowler
#
# [292 rows x 5 columns]

# %%
df_orange_cap_with_role = df_orange_cap.merge(df_players, left_on="batsmanName", right_on="name")
df_orange_cap_with_role
# Out:
#          batsmanName  runs             name          team    battingStyle  \
# 0        ShubmanGill  1851      ShubmanGill           KKR  Right hand Bat
# 1       FafduPlessis  1831     FafduPlessis   Super Kings  Right hand Bat
# 2     RuturajGaikwad  1593   RuturajGaikwad   Super Kings  Right hand Bat
# 3            KLRahul  1516          KLRahul  Punjab Kings  Right hand Bat
# 4         JosButtler  1509       JosButtler        Royals  Right hand Bat
# ..               ...   ...              ...           ...             ...
# 259    ShahbazNadeem     0    ShahbazNadeem     Sunrisers  Right hand Bat
# 260      SanjayYadav     0      SanjayYadav        Mumbai   Left hand Bat
# 261       TNatarajan     0       TNatarajan     Sunrisers   Left hand Bat
# 262        YashDayal     0        YashDayal        Titans  Right hand Bat
# 263  TusharDeshpande     0  TusharDeshpande   Super Kings   Left hand Bat
#
#                bowlingStyle          playingRole
# 0        Right arm Offbreak       Opening Batter
# 1                  Legbreak  Middle order Batter
# 2        Right arm Offbreak               Batter
# 3             Not Available  Wicketkeeper Batter
# 4             Not Available  Wicketkeeper Batter
# ..                      ...                  ...
# 259  Slow Left arm Orthodox               Bowler
# 260  Slow Left arm Orthodox           Allrounder
# 261         Left arm Medium               Bowler
# 262    Left arm Medium fast               Bowler
# 263        Right arm Medium               Bowler
#
# [264 rows x 7 columns]

# %%
df_wicket_keeper = df_orange_cap_with_role[df_orange_cap_with_role["playingRole"].str.contains("Wicket", case=False)].head(1)
df_wicket_keeper
if df_wicket_keeper.empty:
    df_wicket_keeper = df_orange_cap_with_role.head(1)

df_wicket_keeper
# Out:
#   batsmanName  runs     name          team    battingStyle   bowlingStyle  \
# 3     KLRahul  1516  KLRahul  Punjab Kings  Right hand Bat  Not Available
#
#            playingRole
# 3  Wicketkeeper Batter

# %%
df_wicket_keeper_name = df_wicket_keeper["batsmanName"].values[0]
df_wicket_keeper_name
# Out:
# 'KLRahul'

# %%
# Top 4 batsman are exclude wicket keeper

top_batters = df_orange_cap[df_orange_cap["batsmanName"]!= df_wicket_keeper_name].head(4)

top_batters
# Out:
#       batsmanName  runs
# 0     ShubmanGill  1851
# 1    FafduPlessis  1831
# 2  RuturajGaikwad  1593
# 4      JosButtler  1509

# %% [markdown]
# # My Dream Team of 11 Players

# %%
df_wicket_keeper_name
# Out:
# 'KLRahul'

# %%
df_purple_cap
# Out:
#         bowlerName  wickets
# 0    MohammedShami       67
# 1  YuzvendraChahal       66
# 2     HarshalPatel       65
# 3       RashidKhan       63
# 4        AveshKhan       47

# %%
top_3_allrounders
# Out:
#      batsmanName  runs    bowlerName  wickets
# 43  GlennMaxwell  1214  GlennMaxwell       12
# 46  HardikPandya   960  HardikPandya       11
# 11  AndreRussell   745  AndreRussell       35

# %%
best_11= list(top_batters.batsmanName.values)
best_11.append(df_wicket_keeper_name)
best_11.extend(df_purple_cap["bowlerName"].head(3).values)
best_11.extend(top_3_allrounders.batsmanName.values)
best_11
# Out:
# ['ShubmanGill',
#  'FafduPlessis',
#  'RuturajGaikwad',
#  'JosButtler',
#  'KLRahul',
#  'MohammedShami',
#  'YuzvendraChahal',
#  'HarshalPatel',
#  'GlennMaxwell',
#  'HardikPandya',
#  'AndreRussell']

# %%
print("--- My Best XI ---")
for i, player in enumerate(best_11,1):
    print(f"{i}. {player}")
# Out:
# --- My Best XI ---
# 1. ShubmanGill
# 2. FafduPlessis
# 3. RuturajGaikwad
# 4. JosButtler
# 5. KLRahul
# 6. MohammedShami
# 7. YuzvendraChahal
# 8. HarshalPatel
# 9. GlennMaxwell
# 10. HardikPandya
# 11. AndreRussell
